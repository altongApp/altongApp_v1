# %% [markdown]
# # Altong App - 전문의약품 크롤링

# %% [markdown]
# 네이버 의약품 백과사전에서 '구분'이 '전문의약품'인 약품들 크롤링하여 데이터 수집하는 코드입니다.

# %% [markdown]
# ### 일단 새 가상환경 생성 해봅시다

# %%
# conda 가상환경 생성
# !conda create -n medicine_crawler python=3.10 -y

# 가상환경에 패키지 설치
# !conda install -n medicine_crawler pandas -y
# !conda run -n medicine_crawler pip install playwright nest_asyncio

# Playwright 브라우저 설치
# !conda run -n medicine_crawler playwright install chromium

# 주피터 커널로 등록
# !conda install -n medicine_crawler ipykernel -y
# !conda run -n medicine_crawler python -m ipykernel install --user --name medicine_crawler --display-name "medicine_crawler"
# Out:
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/medicine_crawler
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.11.4  |       hca03da5_0         128 KB
#     expat-2.7.3                |       h982b769_0         139 KB
#     libcxx-20.1.8              |       hd7fd590_1         306 KB
#     libzlib-1.3.1              |       h5f15de7_0          47 KB
#     ncurses-6.5                |       hee39554_0         886 KB
#     openssl-3.0.18             |       h9b4081a_0         3.1 MB
#     pip-25.3                   |     pyhc872135_0         1.1 MB
#     python-3.10.19             |       hf701271_0        11.5 MB
#     readline-8.3               |       h0b18652_0         464 KB
#     setuptools-80.9.0          |  py310hca03da5_0         1.4 MB
#     sqlite-3.51.0              |       hab6afd1_0         1.1 MB
#     tk-8.6.15                  |       hcd8a7d5_0         3.3 MB
#     wheel-0.45.1               |  py310hca03da5_0         116 KB
#     zlib-1.3.1                 |       h5f15de7_0          77 KB
#     ------------------------------------------------------------
#                                            Total:        23.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              pkgs/main/osx-arm64::bzip2-1.0.8-h80987f9_6
#   ca-certificates    pkgs/main/osx-arm64::ca-certificates-2025.11.4-hca03da5_0
#   expat              pkgs/main/osx-arm64::expat-2.7.3-h982b769_0
#   libcxx             pkgs/main/osx-arm64::libcxx-20.1.8-hd7fd590_1
#   libffi             pkgs/main/osx-arm64::libffi-3.4.4-hca03da5_1
#   libzlib            pkgs/main/osx-arm64::libzlib-1.3.1-h5f15de7_0
#   ncurses            pkgs/main/osx-arm64::ncurses-6.5-hee39554_0
#   openssl            pkgs/main/osx-arm64::openssl-3.0.18-h9b4081a_0
#   pip                pkgs/main/noarch::pip-25.3-pyhc872135_0
#   python             pkgs/main/osx-arm64::python-3.10.19-hf701271_0
#   readline           pkgs/main/osx-arm64::readline-8.3-h0b18652_0
#   setuptools         pkgs/main/osx-arm64::setuptools-80.9.0-py310hca03da5_0
#   sqlite             pkgs/main/osx-arm64::sqlite-3.51.0-hab6afd1_0
#   tk                 pkgs/main/osx-arm64::tk-8.6.15-hcd8a7d5_0
#   tzdata             pkgs/main/noarch::tzdata-2025b-h04d1e81_0
#   wheel              pkgs/main/osx-arm64::wheel-0.45.1-py310hca03da5_0
#   xz                 pkgs/main/osx-arm64::xz-5.6.4-h80987f9_1
#   zlib               pkgs/main/osx-arm64::zlib-1.3.1-h5f15de7_0
#
#
#
# Downloading and Extracting Packages:
# python-3.10.19       | 11.5 MB   |                                       |   0%
# tk-8.6.15            | 3.3 MB    |                                       |   0%
#
# openssl-3.0.18       | 3.1 MB    |                                       |   0%
#
#
# setuptools-80.9.0    | 1.4 MB    |                                       |   0%
#
#
#
# sqlite-3.51.0        | 1.1 MB    |                                       |   0%
#
#
#
#
# pip-25.3             | 1.1 MB    |                                       |   0%
#
#
#
#
#
# ncurses-6.5          | 886 KB    |                                       |   0%
#
#
#
#
#
#
# readline-8.3         | 464 KB    |                                       |   0%
#
#
#
#
#
#
#
# libcxx-20.1.8        | 306 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# expat-2.7.3          | 139 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 128 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 116 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.3.1           | 77 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 47 KB     |                                       |   0%
# python-3.10.19       | 11.5 MB   |                                       |   0%
#
#
# setuptools-80.9.0    | 1.4 MB    | 4                                     |   1%
#
#
#
# sqlite-3.51.0        | 1.1 MB    | 5                                     |   1%
#
# openssl-3.0.18       | 3.1 MB    | 1                                     |   1%
# python-3.10.19       | 11.5 MB   | ##4                                   |   7%
#
#
# setuptools-80.9.0    | 1.4 MB    | ############4                         |  34%
#
#
#
# sqlite-3.51.0        | 1.1 MB    | #####################8                |  59%
#
#
# setuptools-80.9.0    | 1.4 MB    | ##########################9           |  73%
# tk-8.6.15            | 3.3 MB    | ##############5                       |  39%
#
# openssl-3.0.18       | 3.1 MB    | #######1                              |  19%
#
#
#
# sqlite-3.51.0        | 1.1 MB    | ##################################5   |  93%
#
#
#
# python-3.10.19       | 11.5 MB   | ###8                                  |  10%
#
#
#
# sqlite-3.51.0        | 1.1 MB    | ##################################### | 100%
#
#
# setuptools-80.9.0    | 1.4 MB    | ##################################### | 100%
#
# openssl-3.0.18       | 3.1 MB    | ###########4                          |  31%
# python-3.10.19       | 11.5 MB   | ######                                |  16%
#
# openssl-3.0.18       | 3.1 MB    | ##############8                       |  40%
# tk-8.6.15            | 3.3 MB    | ###############################2      |  85%
#
#
#
#
# pip-25.3             | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
# ncurses-6.5          | 886 KB    | 6                                     |   2%
# tk-8.6.15            | 3.3 MB    | ##################################### | 100%
#
#
#
#
#
# python-3.10.19       | 11.5 MB   | ##########2                           |  28%
#
# openssl-3.0.18       | 3.1 MB    | ###################################   |  95%
#
#
#
#
# pip-25.3             | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
# readline-8.3         | 464 KB    | #2                                    |   3%
#
# openssl-3.0.18       | 3.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# libcxx-20.1.8        | 306 KB    | #9                                    |   5%
#
#
#
#
#
#
# readline-8.3         | 464 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libcxx-20.1.8        | 306 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# expat-2.7.3          | 139 KB    | ####2                                 |  12%
#
#
#
#
#
#
#
#
# expat-2.7.3          | 139 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 128 KB    | ####6                                 |  12%
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 11.5 MB   | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.3.1           | 77 KB     | #######7                              |  21%
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 116 KB    | #####1                                |  14%
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.3.1           | 77 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 116 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 47 KB     | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 47 KB     | ##################################### | 100%
#
#
# setuptools-80.9.0    | 1.4 MB    | ##################################### | 100%
#
#
# python-3.10.19       | 11.5 MB   | #########################8            |  70%
# python-3.10.19       | 11.5 MB   | #################################3    |  90%
#
#
#
#
# pip-25.3             | 1.1 MB    | ##################################### | 100%
#
#
#
#
# pip-25.3             | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
# readline-8.3         | 464 KB    | ##################################### | 100%
#
#
#
#
#
#
# python-3.10.19       | 11.5 MB   | ##################################### | 100%
#
#
#
#
#
#
#
# libcxx-20.1.8        | 306 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libcxx-20.1.8        | 306 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# expat-2.7.3          | 139 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# expat-2.7.3          | 139 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 128 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 128 KB    | ##################################### | 100%
#
# openssl-3.0.18       | 3.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.3.1           | 77 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.3.1           | 77 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 47 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 47 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 116 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 116 KB    | ##################################### | 100%
#
#
#
#
#
# ncurses-6.5          | 886 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate medicine_crawler
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/medicine_crawler
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.4.2           |  py310h03d0aa3_1         105 KB
#     libgfortran5-15.2.0        |       hb654fa1_1         742 KB
#     libopenblas-0.3.30         |       hf2bb037_2         4.1 MB
#     llvm-openmp-20.1.8         |       he822017_0         327 KB
#     numexpr-2.14.1             |  py310h5fbe615_0         165 KB
#     numpy-2.2.5                |  py310h40d09ce_2          11 KB
#     numpy-base-2.2.5           |  py310h855c928_2         5.7 MB
#     pandas-2.3.3               |  py310h3f644e9_1        11.0 MB
#     python-dateutil-2.9.0post0 |  py310hca03da5_2         285 KB
#     python-tzdata-2025.2       |     pyhd3eb1b0_0         141 KB
#     pytz-2025.2                |  py310hca03da5_0         232 KB
#     six-1.17.0                 |  py310hca03da5_0          33 KB
#     ------------------------------------------------------------
#                                            Total:        22.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-arm64::blas-1.0-openblas
#   bottleneck         pkgs/main/osx-arm64::bottleneck-1.4.2-py310h03d0aa3_1
#   libgfortran5       pkgs/main/osx-arm64::libgfortran5-15.2.0-hb654fa1_1
#   libopenblas        pkgs/main/osx-arm64::libopenblas-0.3.30-hf2bb037_2
#   llvm-openmp        pkgs/main/osx-arm64::llvm-openmp-20.1.8-he822017_0
#   numexpr            pkgs/main/osx-arm64::numexpr-2.14.1-py310h5fbe615_0
#   numpy              pkgs/main/osx-arm64::numpy-2.2.5-py310h40d09ce_2
#   numpy-base         pkgs/main/osx-arm64::numpy-base-2.2.5-py310h855c928_2
#   pandas             pkgs/main/osx-arm64::pandas-2.3.3-py310h3f644e9_1
#   python-dateutil    pkgs/main/osx-arm64::python-dateutil-2.9.0post0-py310hca03da5_2
#   python-tzdata      pkgs/main/noarch::python-tzdata-2025.2-pyhd3eb1b0_0
#   pytz               pkgs/main/osx-arm64::pytz-2025.2-py310hca03da5_0
#   six                pkgs/main/osx-arm64::six-1.17.0-py310hca03da5_0
#
#
#
# Downloading and Extracting Packages:
# pandas-2.3.3         | 11.0 MB   |                                       |   0%
# numpy-base-2.2.5     | 5.7 MB    |                                       |   0%
#
# libopenblas-0.3.30   | 4.1 MB    |                                       |   0%
#
#
# libgfortran5-15.2.0  | 742 KB    |                                       |   0%
#
#
#
# llvm-openmp-20.1.8   | 327 KB    |                                       |   0%
#
#
#
#
# python-dateutil-2.9. | 285 KB    |                                       |   0%
#
#
#
#
#
# pytz-2025.2          | 232 KB    |                                       |   0%
#
#
#
#
#
#
# numexpr-2.14.1       | 165 KB    |                                       |   0%
#
#
#
#
#
#
#
# python-tzdata-2025.2 | 141 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# bottleneck-1.4.2     | 105 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# six-1.17.0           | 33 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# numpy-2.2.5          | 11 KB     |                                       |   0%
#
# libopenblas-0.3.30   | 4.1 MB    | #1                                    |   3%
#
#
#
# llvm-openmp-20.1.8   | 327 KB    | ##########8                           |  29%
#
#
# libgfortran5-15.2.0  | 742 KB    | ######3                               |  17%
# pandas-2.3.3         | 11.0 MB   |                                       |   0%
#
#
#
# llvm-openmp-20.1.8   | 327 KB    | ##################################### | 100%
#
#
# libgfortran5-15.2.0  | 742 KB    | ##################################### | 100%
#
#
#
# llvm-openmp-20.1.8   | 327 KB    | ##################################### | 100%
#
#
# libgfortran5-15.2.0  | 742 KB    | ##################################### | 100%
#
# libopenblas-0.3.30   | 4.1 MB    | ###################9                  |  54%
# numpy-base-2.2.5     | 5.7 MB    | #######                               |  19%
#
#
#
#
#
# pytz-2025.2          | 232 KB    | ##5                                   |   7%
#
#
#
#
# pandas-2.3.3         | 11.0 MB   | ###3                                  |   9%
#
#
#
#
# python-dateutil-2.9. | 285 KB    | ##################################### | 100%
#
#
#
#
# python-dateutil-2.9. | 285 KB    | ##################################### | 100%
#
# libopenblas-0.3.30   | 4.1 MB    | ###############################5      |  85%
# pandas-2.3.3         | 11.0 MB   | #####1                                |  14%
#
#
#
#
#
#
# numexpr-2.14.1       | 165 KB    | ###5                                  |  10%
#
#
#
#
#
#
# numexpr-2.14.1       | 165 KB    | ##################################### | 100%
#
#
#
#
#
# pytz-2025.2          | 232 KB    | #################################2    |  90%
#
#
#
#
#
# pandas-2.3.3         | 11.0 MB   | ########5                             |  23%
#
# libopenblas-0.3.30   | 4.1 MB    | ##################################### | 100%
# numpy-base-2.2.5     | 5.7 MB    | ################3                     |  44%
#
#
#
#
#
#
# numexpr-2.14.1       | 165 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# python-tzdata-2025.2 | 141 KB    | ####1                                 |  11%
#
#
#
#
#
#
#
#
# bottleneck-1.4.2     | 105 KB    | #####6                                |  15%
#
#
#
#
#
#
#
#
# bottleneck-1.4.2     | 105 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pandas-2.3.3         | 11.0 MB   | ##########9                           |  30%
#
#
#
#
#
#
#
#
#
# six-1.17.0           | 33 KB     | ##################################### | 100%
# numpy-base-2.2.5     | 5.7 MB    | ####################5                 |  56%
#
#
#
#
#
#
#
# python-tzdata-2025.2 | 141 KB    | ##################################### | 100%
#
# libopenblas-0.3.30   | 4.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# six-1.17.0           | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# bottleneck-1.4.2     | 105 KB    | ##################################### | 100%
#
#
#
#
#
# pytz-2025.2          | 232 KB    | ##################################### | 100%
# numpy-base-2.2.5     | 5.7 MB    | ########################3             |  66%
#
#
#
#
#
#
#
#
#
#
# numpy-2.2.5          | 11 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# pandas-2.3.3         | 11.0 MB   | #############1                        |  36%
#
#
#
#
#
#
#
#
#
#
# numpy-2.2.5          | 11 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# python-tzdata-2025.2 | 141 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# python-tzdata-2025.2 | 141 KB    | ##################################### | 100%
# pandas-2.3.3         | 11.0 MB   | #################8                    |  48%
# pandas-2.3.3         | 11.0 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting playwright
#   Downloading playwright-1.56.0-py3-none-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting nest_asyncio
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting pyee<14,>=13 (from playwright)
#   Using cached pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting greenlet<4.0.0,>=3.1.1 (from playwright)
#   Downloading greenlet-3.2.4-cp310-cp310-macosx_11_0_universal2.whl.metadata (4.1 kB)
# Collecting typing-extensions (from pyee<14,>=13->playwright)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading playwright-1.56.0-py3-none-macosx_11_0_arm64.whl (39.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/39.4 MB ? eta -:--:--
#    ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/39.4 MB 26.9 MB/s eta 0:00:02
#    ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/39.4 MB 21.4 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━ 14.2/39.4 MB 24.0 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━ 18.1/39.4 MB 22.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━ 25.2/39.4 MB 25.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━ 30.9/39.4 MB 26.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━ 35.7/39.4 MB 25.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 24.3 MB/s  0:00:01
# Downloading greenlet-3.2.4-cp310-cp310-macosx_11_0_universal2.whl (271 kB)
# Using cached pyee-13.0.0-py3-none-any.whl (15 kB)
# Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing-extensions, nest_asyncio, greenlet, pyee, playwright
#
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━ 4/5 [playwright]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━ 4/5 [playwright]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━ 4/5 [playwright]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━ 4/5 [playwright]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━ 4/5 [playwright]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [playwright]
#
# Successfully installed greenlet-3.2.4 nest_asyncio-1.6.0 playwright-1.56.0 pyee-13.0.0 typing-extensions-4.15.0
#
# Downloading Chromium 141.0.7390.37 (playwright build v1194) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1194/chromium-mac-arm64.zip
# |                                                                                |   0% of 129.7 MiB
# |■■■■■■■■                                                                        |  10% of 129.7 MiB
# |■■■■■■■■■■■■■■■■                                                                |  20% of 129.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 129.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 129.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 129.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 129.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 129.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 129.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 129.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 129.7 MiB
# Chromium 141.0.7390.37 (playwright build v1194) downloaded to /Users/choeminju/Library/Caches/ms-playwright/chromium-1194
# Downloading Chromium Headless Shell 141.0.7390.37 (playwright build v1194) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1194/chromium-headless-shell-mac-arm64.zip
# |                                                                                |   0% of 81.7 MiB
# |■■■■■■■■                                                                        |  10% of 81.7 MiB
# |■■■■■■■■■■■■■■■■                                                                |  20% of 81.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 81.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 81.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 81.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 81.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 81.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 81.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 81.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 81.7 MiB
# Chromium Headless Shell 141.0.7390.37 (playwright build v1194) downloaded to /Users/choeminju/Library/Caches/ms-playwright/chromium_headless_shell-1194
#
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/medicine_crawler
#
#   added / updated specs:
#     - ipykernel
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appnope-0.1.4              |  py310hca03da5_0          14 KB
#     asttokens-3.0.0            |  py310hca03da5_0          41 KB
#     comm-0.2.3                 |  py310hca03da5_0          15 KB
#     debugpy-1.8.16             |  py310h50f4ffc_1         2.1 MB
#     decorator-5.2.1            |  py310hca03da5_0          38 KB
#     exceptiongroup-1.3.0       |  py310hca03da5_0          40 KB
#     executing-2.2.1            |  py310hca03da5_0         324 KB
#     ipykernel-6.31.0           |  py310h7eb115d_0         201 KB
#     ipython-8.30.0             |  py310hca03da5_0         1.1 MB
#     jedi-0.19.2                |  py310hca03da5_0         1.1 MB
#     jupyter_client-8.6.3       |  py310hca03da5_1         182 KB
#     jupyter_core-5.8.1         |  py310hca03da5_0          84 KB
#     libsodium-1.0.20           |       h897f8a9_0         224 KB
#     matplotlib-inline-0.2.1    |  py310hca03da5_0          17 KB
#     nest-asyncio-1.6.0         |  py310hca03da5_0          15 KB
#     packaging-25.0             |  py310hca03da5_1         164 KB
#     parso-0.8.5                |  py310hca03da5_0         186 KB
#     pexpect-4.9.0              |  py310hca03da5_1         131 KB
#     platformdirs-4.5.0         |  py310hca03da5_0          37 KB
#     prompt-toolkit-3.0.52      |  py310hca03da5_1         567 KB
#     prompt_toolkit-3.0.52      |       hd3eb1b0_1           5 KB
#     psutil-7.0.0               |  py310haa24f5a_1         428 KB
#     ptyprocess-0.7.0           |     pyhd3eb1b0_3          18 KB
#     pure_eval-0.2.3            |  py310hca03da5_0          29 KB
#     pygments-2.19.2            |  py310hca03da5_0         4.4 MB
#     pyzmq-27.1.0               |  py310h5a8c52c_1         304 KB
#     stack_data-0.6.3           |  py310hca03da5_0          55 KB
#     tornado-6.5.1              |  py310h80987f9_0         679 KB
#     traitlets-5.14.3           |  py310hca03da5_0         179 KB
#     typing-extensions-4.15.0   |  py310hca03da5_0          12 KB
#     typing_extensions-4.15.0   |  py310hca03da5_0          81 KB
#     wcwidth-0.2.13             |  py310hca03da5_0          72 KB
#     zeromq-4.3.5               |       h2c7f8f0_1         277 KB
#     ------------------------------------------------------------
#                                            Total:        13.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   appnope            pkgs/main/osx-arm64::appnope-0.1.4-py310hca03da5_0
#   asttokens          pkgs/main/osx-arm64::asttokens-3.0.0-py310hca03da5_0
#   comm               pkgs/main/osx-arm64::comm-0.2.3-py310hca03da5_0
#   debugpy            pkgs/main/osx-arm64::debugpy-1.8.16-py310h50f4ffc_1
#   decorator          pkgs/main/osx-arm64::decorator-5.2.1-py310hca03da5_0
#   exceptiongroup     pkgs/main/osx-arm64::exceptiongroup-1.3.0-py310hca03da5_0
#   executing          pkgs/main/osx-arm64::executing-2.2.1-py310hca03da5_0
#   ipykernel          pkgs/main/osx-arm64::ipykernel-6.31.0-py310h7eb115d_0
#   ipython            pkgs/main/osx-arm64::ipython-8.30.0-py310hca03da5_0
#   jedi               pkgs/main/osx-arm64::jedi-0.19.2-py310hca03da5_0
#   jupyter_client     pkgs/main/osx-arm64::jupyter_client-8.6.3-py310hca03da5_1
#   jupyter_core       pkgs/main/osx-arm64::jupyter_core-5.8.1-py310hca03da5_0
#   libsodium          pkgs/main/osx-arm64::libsodium-1.0.20-h897f8a9_0
#   matplotlib-inline  pkgs/main/osx-arm64::matplotlib-inline-0.2.1-py310hca03da5_0
#   nest-asyncio       pkgs/main/osx-arm64::nest-asyncio-1.6.0-py310hca03da5_0
#   packaging          pkgs/main/osx-arm64::packaging-25.0-py310hca03da5_1
#   parso              pkgs/main/osx-arm64::parso-0.8.5-py310hca03da5_0
#   pexpect            pkgs/main/osx-arm64::pexpect-4.9.0-py310hca03da5_1
#   platformdirs       pkgs/main/osx-arm64::platformdirs-4.5.0-py310hca03da5_0
#   prompt-toolkit     pkgs/main/osx-arm64::prompt-toolkit-3.0.52-py310hca03da5_1
#   prompt_toolkit     pkgs/main/noarch::prompt_toolkit-3.0.52-hd3eb1b0_1
#   psutil             pkgs/main/osx-arm64::psutil-7.0.0-py310haa24f5a_1
#   ptyprocess         pkgs/main/noarch::ptyprocess-0.7.0-pyhd3eb1b0_3
#   pure_eval          pkgs/main/osx-arm64::pure_eval-0.2.3-py310hca03da5_0
#   pygments           pkgs/main/osx-arm64::pygments-2.19.2-py310hca03da5_0
#   pyzmq              pkgs/main/osx-arm64::pyzmq-27.1.0-py310h5a8c52c_1
#   stack_data         pkgs/main/osx-arm64::stack_data-0.6.3-py310hca03da5_0
#   tornado            pkgs/main/osx-arm64::tornado-6.5.1-py310h80987f9_0
#   traitlets          pkgs/main/osx-arm64::traitlets-5.14.3-py310hca03da5_0
#   typing-extensions  pkgs/main/osx-arm64::typing-extensions-4.15.0-py310hca03da5_0
#   typing_extensions  pkgs/main/osx-arm64::typing_extensions-4.15.0-py310hca03da5_0
#   wcwidth            pkgs/main/osx-arm64::wcwidth-0.2.13-py310hca03da5_0
#   zeromq             pkgs/main/osx-arm64::zeromq-4.3.5-h2c7f8f0_1
#
#
#
# Downloading and Extracting Packages:
# pygments-2.19.2      | 4.4 MB    |                                       |   0%
# debugpy-1.8.16       | 2.1 MB    |                                       |   0%
#
# ipython-8.30.0       | 1.1 MB    |                                       |   0%
#
#
# jedi-0.19.2          | 1.1 MB    |                                       |   0%
#
#
#
# tornado-6.5.1        | 679 KB    |                                       |   0%
#
#
#
#
# prompt-toolkit-3.0.5 | 567 KB    |                                       |   0%
#
#
#
#
#
# psutil-7.0.0         | 428 KB    |                                       |   0%
#
#
#
#
#
#
# executing-2.2.1      | 324 KB    |                                       |   0%
#
#
#
#
#
#
#
# pyzmq-27.1.0         | 304 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 277 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libsodium-1.0.20     | 224 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.31.0     | 201 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# parso-0.8.5          | 186 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_client-8.6.3 | 182 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# traitlets-5.14.3     | 179 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-25.0       | 164 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pexpect-4.9.0        | 131 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_core-5.8.1   | 84 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 81 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wcwidth-0.2.13       | 72 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stack_data-0.6.3     | 55 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# asttokens-3.0.0      | 41 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# exceptiongroup-1.3.0 | 40 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# pygments-2.19.2      | 4.4 MB    | #                                     |   3%
#
# ipython-8.30.0       | 1.1 MB    | 5                                     |   1%
# debugpy-1.8.16       | 2.1 MB    | 2                                     |   1%
#
#
#
# tornado-6.5.1        | 679 KB    | 8                                     |   2%
#
#
#
# tornado-6.5.1        | 679 KB    | ##################################### | 100%
#
# ipython-8.30.0       | 1.1 MB    | ######################4               |  61%
# pygments-2.19.2      | 4.4 MB    | #######1                              |  19%
#
#
# jedi-0.19.2          | 1.1 MB    | ####################################1 |  98%
#
# ipython-8.30.0       | 1.1 MB    | ##################################### | 100%
#
#
# jedi-0.19.2          | 1.1 MB    | ##################################### | 100%
#
#
#
#
# prompt-toolkit-3.0.5 | 567 KB    | #                                     |   3%
#
#
#
#
# prompt-toolkit-3.0.5 | 567 KB    | ##################################### | 100%
#
#
#
#
#
#
# executing-2.2.1      | 324 KB    | #8                                    |   5%
#
#
#
#
#
# pygments-2.19.2      | 4.4 MB    | #############################6        |  80%
# debugpy-1.8.16       | 2.1 MB    | #################################6    |  91%
#
#
#
#
#
#
# executing-2.2.1      | 324 KB    | ##################################### | 100%
#
#
#
#
#
# psutil-7.0.0         | 428 KB    | ##################################### | 100%
# debugpy-1.8.16       | 2.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# pyzmq-27.1.0         | 304 KB    | #9                                    |   5%
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 277 KB    | ##1                                   |   6%
#
#
#
#
#
#
#
# pygments-2.19.2      | 4.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libsodium-1.0.20     | 224 KB    | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
# libsodium-1.0.20     | 224 KB    | ##################################### | 100%
#
#
#
# tornado-6.5.1        | 679 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.31.0     | 201 KB    | ##9                                   |   8%
#
#
#
# tornado-6.5.1        | 679 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 277 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.31.0     | 201 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_client-8.6.3 | 182 KB    | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# parso-0.8.5          | 186 KB    | ###1                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_client-8.6.3 | 182 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# parso-0.8.5          | 186 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-25.0       | 164 KB    | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-25.0       | 164 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pexpect-4.9.0        | 131 KB    | ####5                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pexpect-4.9.0        | 131 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 81 KB     | #######3                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wcwidth-0.2.13       | 72 KB     | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 81 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_core-5.8.1   | 84 KB     | #######                               |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wcwidth-0.2.13       | 72 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_core-5.8.1   | 84 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stack_data-0.6.3     | 55 KB     | ##########8                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stack_data-0.6.3     | 55 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# asttokens-3.0.0      | 41 KB     | ##############4                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# exceptiongroup-1.3.0 | 40 KB     | ##############7                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# exceptiongroup-1.3.0 | 40 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# asttokens-3.0.0      | 41 KB     | ##################################### | 100%
#
#
#
#
# prompt-toolkit-3.0.5 | 567 KB    | ##################################### | 100%
#
#
#
#
# prompt-toolkit-3.0.5 | 567 KB    | ##################################### | 100%
#
# ipython-8.30.0       | 1.1 MB    | ##################################### | 100%
#
# ipython-8.30.0       | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# traitlets-5.14.3     | 179 KB    | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
# traitlets-5.14.3     | 179 KB    | ##################################### | 100%
#
#
#
#
#
# psutil-7.0.0         | 428 KB    | ##################################### | 100%
#
#
#
#
#
# psutil-7.0.0         | 428 KB    | ##################################### | 100%
#
#
#
#
#
#
# executing-2.2.1      | 324 KB    | ##################################### | 100%
#
#
#
#
#
#
# executing-2.2.1      | 324 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# pyzmq-27.1.0         | 304 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# pyzmq-27.1.0         | 304 KB    | ##################################### | 100%
# debugpy-1.8.16       | 2.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libsodium-1.0.20     | 224 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libsodium-1.0.20     | 224 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 277 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 277 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.31.0     | 201 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.31.0     | 201 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_client-8.6.3 | 182 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_client-8.6.3 | 182 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# parso-0.8.5          | 186 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# parso-0.8.5          | 186 KB    | ##################################### | 100%
#
#
# jedi-0.19.2          | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-25.0       | 164 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-25.0       | 164 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 81 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 81 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pexpect-4.9.0        | 131 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pexpect-4.9.0        | 131 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wcwidth-0.2.13       | 72 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wcwidth-0.2.13       | 72 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_core-5.8.1   | 84 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_core-5.8.1   | 84 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stack_data-0.6.3     | 55 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stack_data-0.6.3     | 55 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# exceptiongroup-1.3.0 | 40 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# exceptiongroup-1.3.0 | 40 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# asttokens-3.0.0      | 41 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# asttokens-3.0.0      | 41 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# traitlets-5.14.3     | 179 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pygments-2.19.2      | 4.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Installed kernelspec medicine_crawler in /Users/choeminju/Library/Jupyter/kernels/medicine_crawler

# %% [markdown]
# ## 먼저 테스트 코드로 url 20개
# 1. 정해둔 개수만큼 약 url을 수집한다.
# 2. 각 url을 들어가서 '구분' 필드 값이 '전문의약품'일 경우에만 데이터를 수집한다
# 3. 반복

# %%
"""
네이버 의약품 백과사전 전문의약품 크롤링 - 테스트 버전
- URL 30개만 수집해서 테스트
- 실제 크롤링과 동일한 방식으로 작동
"""

import asyncio
from playwright.async_api import async_playwright
import pandas as pd
from datetime import datetime
import json
import time

# 주피터 노트북용 이벤트 루프 설정
import nest_asyncio
nest_asyncio.apply()


async def get_medicine_classification(page, url, max_retries=3):
    """
    약품 상세 페이지에서 '구분' 확인
    전문의약품이면 True, 아니면 False 반환
    """
    for attempt in range(max_retries):
        try:
            await page.goto(url, wait_until='networkidle', timeout=30000)
            await asyncio.sleep(2)  # 페이지 로딩 대기
            
            # 테이블에서 '구분' 찾기
            rows = await page.locator('table.tmp_profile_tb tr').all()
            
            for row in rows:
                th_text = await row.locator('th').inner_text()
                if '구분' in th_text:
                    td_text = await row.locator('td').inner_text()
                    classification = td_text.strip()
                    print(f"    구분: {classification}")
                    return classification == '전문의약품'
            
            print(f"    ⚠️ '구분' 필드를 찾을 수 없음")
            return False
            
        except Exception as e:
            print(f"    ⚠️ 구분 확인 실패 (시도 {attempt + 1}/{max_retries}): {e}")
            if attempt < max_retries - 1:
                await asyncio.sleep(3)
            else:
                return False


async def scrape_medicine_detail(page, url, max_retries=3):
    """개별 의약품 상세 정보 크롤링"""
    for attempt in range(max_retries):
        try:
            await page.goto(url, wait_until='networkidle', timeout=30000)
            await asyncio.sleep(2)
            
            medicine_data = {
                'url': url,
                'doc_id': url.split('docId=')[1].split('&')[0] if 'docId=' in url else None
            }
            
            # 약품명
            try:
                title = await page.locator('h2.headword').inner_text()
                medicine_data['약품명'] = title.strip()
            except:
                medicine_data['약품명'] = None
            
            # 이미지 URL 추출 (a 태그의 href에서 imageUrl 파라미터 추출)
            try:
                print(f"      🔍 이미지 URL 추출 시도...")
                # span.img_box 안의 a 태그 찾기 (first는 await 필요 없음)
                img_link = page.locator('span.img_box > a').first
                
                # a 태그가 실제로 존재하는지 확인
                count = await img_link.count()
                if count > 0:
                    print(f"      ✓ a 태그 찾음")
                    href = await img_link.get_attribute('href')
                    print(f"      ✓ href 값: {href}")
                    
                    # href에서 imageUrl 파라미터 추출
                    if href and 'imageUrl=' in href:
                        print(f"      ✓ imageUrl 파라미터 존재")
                        import urllib.parse
                        # URL 파싱
                        parsed = urllib.parse.urlparse(href)
                        params = urllib.parse.parse_qs(parsed.query)
                        print(f"      ✓ 파싱된 파라미터: {list(params.keys())}")
                        
                        # imageUrl 파라미터 디코딩
                        if 'imageUrl' in params:
                            image_url = params['imageUrl'][0]
                            print(f"      ✅ 이미지 URL 추출 성공!")
                            print(f"      📷 URL: {image_url[:100]}...")
                            medicine_data['이미지_URL'] = image_url
                        else:
                            print(f"      ❌ imageUrl 파라미터 없음")
                            medicine_data['이미지_URL'] = None
                    else:
                        print(f"      ❌ href에 imageUrl 파라미터 없음")
                        medicine_data['이미지_URL'] = None
                else:
                    print(f"      ❌ a 태그를 찾을 수 없음")
                    medicine_data['이미지_URL'] = None
            except Exception as e:
                print(f"      ⚠️ 이미지 URL 추출 실패: {e}")
                import traceback
                print(f"      상세 에러: {traceback.format_exc()}")
                medicine_data['이미지_URL'] = None
            
            # 테이블 정보 추출
            try:
                rows = await page.locator('table.tmp_profile_tb tr').all()
                
                for row in rows:
                    th_text = await row.locator('th').inner_text()
                    td_text = await row.locator('td').inner_text()
                    
                    key = th_text.strip()
                    value = td_text.strip()
                    
                    medicine_data[key] = value
                    
            except Exception as e:
                print(f"      ⚠️ 테이블 파싱 오류: {e}")
            
            # 성분정보
            try:
                content1 = await page.locator('#TABLE_OF_CONTENT1').locator('xpath=following-sibling::p[@class="txt"]').first.inner_text()
                medicine_data['성분정보'] = content1.strip()
            except:
                medicine_data['성분정보'] = None
            
            # 효능효과
            try:
                content2 = await page.locator('#TABLE_OF_CONTENT2').locator('xpath=following-sibling::p[@class="txt"]').first.inner_text()
                medicine_data['효능효과'] = content2.strip()
            except:
                medicine_data['효능효과'] = None
            
            # 용법용량
            try:
                content3 = await page.locator('#TABLE_OF_CONTENT3').locator('xpath=following-sibling::p[@class="txt"]').first.inner_text()
                medicine_data['용법용량'] = content3.strip()
            except:
                medicine_data['용법용량'] = None
            
            # 저장방법
            try:
                content4 = await page.locator('#TABLE_OF_CONTENT4').locator('xpath=following-sibling::p[@class="txt"]').first.inner_text()
                medicine_data['저장방법'] = content4.strip()
            except:
                medicine_data['저장방법'] = None
            
            # 사용기간
            try:
                content5 = await page.locator('#TABLE_OF_CONTENT5').locator('xpath=following-sibling::p[@class="txt"]').first.inner_text()
                medicine_data['사용기간'] = content5.strip()
            except:
                medicine_data['사용기간'] = None
            
            # 사용상의주의사항
            try:
                content6 = await page.locator('#TABLE_OF_CONTENT6').locator('xpath=following-sibling::p[@class="txt"]').first.inner_text()
                medicine_data['사용상의주의사항'] = content6.strip()
            except:
                medicine_data['사용상의주의사항'] = None
            
            return medicine_data
            
        except Exception as e:
            print(f"      ⚠️ 크롤링 실패 (시도 {attempt + 1}/{max_retries}): {e}")
            if attempt < max_retries - 1:
                await asyncio.sleep(3)
            else:
                return None


async def get_test_urls(page, base_url, max_urls=20):
    """테스트용: 20개의 URL만 수집"""
    all_urls = []
    page_num = 1
    
    print(f"\n{'='*60}")
    print(f"🧪 테스트 모드: 최대 {max_urls}개 URL만 수집")
    print(f"{'='*60}")
    
    while len(all_urls) < max_urls:
        print(f"\n📄 페이지 {page_num} URL 수집 중...")
        
        current_url = f"{base_url}&page={page_num}"
        
        try:
            await page.goto(current_url, wait_until='networkidle', timeout=30000)
            await asyncio.sleep(2)
            
            # 현재 페이지의 모든 약품 링크 수집
            links = await page.locator('ul.content_list li a[href*="entry.naver"]').all()
            
            if not links:
                print(f"✓ 페이지 {page_num}에서 더 이상 링크를 찾을 수 없습니다.")
                break
            
            page_urls = []
            for link in links:
                href = await link.get_attribute('href')
                if href and 'entry.naver' in href:
                    full_url = f"https://terms.naver.com{href}" if href.startswith('/') else href
                    if full_url not in all_urls and full_url not in page_urls:  # 중복 제거
                        page_urls.append(full_url)
                        
                        # max_urls 도달하면 중단
                        if len(all_urls) + len(page_urls) >= max_urls:
                            break
            
            all_urls.extend(page_urls[:max_urls - len(all_urls)])
            print(f"  ✓ {len(page_urls)}개 수집 (누적: {len(all_urls)}개)")
            
            # max_urls 도달하면 종료
            if len(all_urls) >= max_urls:
                print(f"\n✅ 목표 {max_urls}개 URL 수집 완료!")
                break
            
            page_num += 1
            await asyncio.sleep(1.5)
            
        except Exception as e:
            print(f"⚠️ 페이지 {page_num} 처리 중 오류: {e}")
            break
    
    return all_urls


async def main_test():
    """테스트용 메인 크롤링 함수"""
    
    base_url = "https://terms.naver.com/medicineSearch.naver?mode=exteriorSearch&shape=&color=&dosageForm=&divisionLine=&identifier="
    
    professional_medicines = []
    failed_urls = []
    skipped_count = 0
    
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False)
        context = await browser.new_context()
        page = await context.new_page()
        
        # 1단계: 테스트용 URL 20개만 수집
        print("=" * 60)
        print("🧪 1단계: 테스트용 URL 20개 수집 중...")
        print("=" * 60)
        
        test_urls = await get_test_urls(page, base_url, max_urls=20)
        print(f"\n✅ {len(test_urls)}개의 테스트 URL 수집 완료!\n")
        
        # URL 저장
        with open('test_medicine_urls.json', 'w', encoding='utf-8') as f:
            json.dump(test_urls, f, ensure_ascii=False, indent=2)
        print("✅ 테스트 URL 목록 저장: test_medicine_urls.json\n")
        
        # 2단계: 각 의약품 상세 정보 크롤링 (전문의약품만)
        print("=" * 60)
        print("🧪 2단계: 전문의약품 필터링 및 크롤링 테스트...")
        print("=" * 60)
        
        for idx, url in enumerate(test_urls, 1):
            print(f"\n[{idx}/{len(test_urls)}] 🔍 {url}")
            
            # 먼저 '구분' 확인
            is_professional = await get_medicine_classification(page, url)
            
            if not is_professional:
                skipped_count += 1
                print(f"  ⏭️  전문의약품 아님 - 스킵 (총 스킵: {skipped_count}개)")
                await asyncio.sleep(1)
                continue
            
            # 전문의약품이면 상세 정보 크롤링
            print(f"  ✅ 전문의약품 확인! 상세 정보 수집 중...")
            medicine_data = await scrape_medicine_detail(page, url)
            
            if medicine_data:
                professional_medicines.append(medicine_data)
                print(f"  ✅ 수집 완료 (전문의약품 총 {len(professional_medicines)}개)")
                
                # 데이터 미리보기
                print(f"      📋 약품명: {medicine_data.get('약품명', 'N/A')}")
                print(f"      📋 업체명: {medicine_data.get('업체명', 'N/A')}")
                print(f"      📋 보험코드: {medicine_data.get('보험코드', 'N/A')}")
            else:
                failed_urls.append(url)
                print(f"  ❌ 수집 실패 - 실패 목록에 추가")
            
            await asyncio.sleep(2)
        
        await browser.close()
    
    # 3단계: 테스트 결과 저장
    print("\n" + "=" * 60)
    print("✅ 테스트 완료! 결과 저장 중...")
    print("=" * 60)
    
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    
    # 전문의약품 데이터 저장
    if professional_medicines:
        df_test = pd.DataFrame(professional_medicines)
        df_test.to_csv(f'test_professional_medicines_{timestamp}.csv', index=False, encoding='utf-8-sig')
        print(f"\n✅ 테스트 데이터 저장: test_professional_medicines_{timestamp}.csv ({len(professional_medicines)}건)")
    
    # 실패 목록 저장
    if failed_urls:
        with open(f'test_failed_urls_{timestamp}.json', 'w', encoding='utf-8') as f:
            json.dump(failed_urls, f, ensure_ascii=False, indent=2)
        print(f"⚠️  실패한 URL: test_failed_urls_{timestamp}.json ({len(failed_urls)}건)")
    
    # 테스트 통계
    print("\n" + "=" * 60)
    print("📊 테스트 통계")
    print("=" * 60)
    print(f"테스트 URL 수: {len(test_urls)}건")
    print(f"전문의약품: {len(professional_medicines)}건")
    print(f"일반의약품 등 (스킵): {skipped_count}건")
    print(f"크롤링 실패: {len(failed_urls)}건")
    print("=" * 60)
    
    # 결과 미리보기
    if professional_medicines:
        df_result = pd.DataFrame(professional_medicines)
        print("\n📋 수집된 데이터 미리보기:")
        print(df_result[['약품명', '구분', '업체명', '보험코드']].head(10))
        print(f"\n📋 수집된 전체 컬럼 ({len(df_result.columns)}개):")
        print(list(df_result.columns))
    
    return df_test if professional_medicines else None, failed_urls


# 주피터 노트북에서 실행
print("🧪 네이버 의약품 백과사전 크롤링 테스트 시작!\n")
print("⚠️  이 테스트는 20개 URL만 수집하여 작동을 확인합니다.\n")
start_time = time.time()

df_result, failed_list = await main_test()

end_time = time.time()
elapsed_time = end_time - start_time
print(f"\n⏱️  총 소요 시간: {elapsed_time/60:.2f}분 ({elapsed_time:.2f}초)")

print("\n✅ 테스트 완료! 문제없으면 전체 크롤링 코드를 실행하세요.")
# Out:
# 🧪 네이버 의약품 백과사전 크롤링 테스트 시작!
#
# ⚠️  이 테스트는 20개 URL만 수집하여 작동을 확인합니다.
#
# ============================================================
# 🧪 1단계: 테스트용 URL 20개 수집 중...
# ============================================================
#
# ============================================================
# 🧪 테스트 모드: 최대 20개 URL만 수집
# ============================================================
#
# 📄 페이지 1 URL 수집 중...
#   ✓ 15개 수집 (누적: 15개)
#
# 📄 페이지 2 URL 수집 중...
#   ✓ 5개 수집 (누적: 20개)
#
# ✅ 목표 20개 URL 수집 완료!
#
# ✅ 20개의 테스트 URL 수집 완료!
#
# ✅ 테스트 URL 목록 저장: test_medicine_urls.json
#
# ============================================================
# 🧪 2단계: 전문의약품 필터링 및 크롤링 테스트...
# ============================================================
#
# [1/20] 🔍 https://terms.naver.com/entry.naver?docId=2146611&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2146611&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114085111242_AL4ED2AS6.jpg%2F200704590.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114085111242_AL4ED2AS6.jpg/200704590.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 1개)
#       📋 약품명: 펠루비정(펠루비프로펜)
#       📋 업체명: 대원제약(주)
#       📋 보험코드: 671803380
#
# [2/20] 🔍 https://terms.naver.com/entry.naver?docId=2134728&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2134728&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_43%2F20250105114357181_U0MYAJ0DW.jpg%2F197900575.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_43/20250105114357181_U0MYAJ0DW.jpg/197900575.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 2개)
#       📋 약품명: 슈다페드정(슈도에페드린염산염)
#       📋 업체명: 삼일제약(주)
#       📋 보험코드: 643900710
#
# [3/20] 🔍 https://terms.naver.com/entry.naver?docId=2141235&cid=51000&categoryId=51000
#     구분: 일반의약품
#   ⏭️  전문의약품 아님 - 스킵 (총 스킵: 1개)
#
# [4/20] 🔍 https://terms.naver.com/entry.naver?docId=2141123&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2141123&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114061556421_HIQI9COXV.jpg%2F197400040.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114061556421_HIQI9COXV.jpg/197400040.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 3개)
#       📋 약품명: 인데놀정10mg(프로프라놀롤염산염)
#       📋 업체명: 동광제약(주)
#       📋 보험코드: 645902470
#
# [5/20] 🔍 https://terms.naver.com/entry.naver?docId=2133054&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2133054&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114064744067_XKTQXBC9Q.jpg%2F199300168.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114064744067_XKTQXBC9Q.jpg/199300168.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 4개)
#       📋 약품명: 바난정(세프포독심프록세틸)
#       📋 업체명: 에이치케이이노엔(주)
#       📋 보험코드: 640000480
#
# [6/20] 🔍 https://terms.naver.com/entry.naver?docId=2132214&cid=51000&categoryId=51000
#     구분: 일반의약품
#   ⏭️  전문의약품 아님 - 스킵 (총 스킵: 2개)
#
# [7/20] 🔍 https://terms.naver.com/entry.naver?docId=2140794&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2140794&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114061529152_1FQO1JJ8F.jpg%2F197200376.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114061529152_1FQO1JJ8F.jpg/197200376.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 5개)
#       📋 약품명: 코데날정
#       📋 업체명: 삼아제약(주)
#       📋 보험코드: 645701150
#
# [8/20] 🔍 https://terms.naver.com/entry.naver?docId=2130361&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2130361&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114103919082_KR7XI2M1B.jpg%2F201308928.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114103919082_KR7XI2M1B.jpg/201308928.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 6개)
#       📋 약품명: 낙소졸정500/20mg
#       📋 업체명: 한미약품(주)
#       📋 보험코드: 643506630
#
# [9/20] 🔍 https://terms.naver.com/entry.naver?docId=2698756&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2698756&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114113800089_7XIKEH677.jpg%2F201501350.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114113800089_7XIKEH677.jpg/201501350.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 7개)
#       📋 약품명: 펠루비서방정(펠루비프로펜)
#       📋 업체명: 대원제약(주)
#       📋 보험코드: 671805860
#
# [10/20] 🔍 https://terms.naver.com/entry.naver?docId=5138923&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=5138923&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_43%2F20250405121254343_ZPUA4RBK0.jpg%2F201800928.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_43/20250405121254343_ZPUA4RBK0.jpg/201800928.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 8개)
#       📋 약품명: 리리카캡슐25mg(프레가발린)
#       📋 업체명: 비아트리스코리아(주)
#       📋 보험코드: 073400230
#
# [11/20] 🔍 https://terms.naver.com/entry.naver?docId=2131001&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2131001&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114104544500_9QXOZISA4.jpg%2F201310719.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114104544500_9QXOZISA4.jpg/201310719.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 9개)
#       📋 약품명: 글리아타민연질캡슐(콜린알포세레이트)
#       📋 업체명: 대웅바이오(주)
#       📋 보험코드: 694000600
#
# [12/20] 🔍 https://terms.naver.com/entry.naver?docId=2141356&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2141356&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114063123819_RHEYRXRRU.jpg%2F198702202.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114063123819_RHEYRXRRU.jpg/198702202.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 10개)
#       📋 약품명: 알프람정0.5mg(알프라졸람)
#       📋 업체명: 환인제약(주)
#       📋 보험코드: 657200490
#
# [13/20] 🔍 https://terms.naver.com/entry.naver?docId=2127865&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2127865&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114095930815_0HVRXB0A4.jpg%2F201200417.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114095930815_0HVRXB0A4.jpg/201200417.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 11개)
#       📋 약품명: 비모보정 500/20mg
#       📋 업체명: (주)엘지화학
#       📋 보험코드: 668903330
#
# [14/20] 🔍 https://terms.naver.com/entry.naver?docId=2141291&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2141291&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114061752317_64E8ES6BN.jpg%2F197700535.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114061752317_64E8ES6BN.jpg/197700535.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 12개)
#       📋 약품명: 삼진디아제팜정2mg
#       📋 업체명: 삼진제약(주)
#       📋 보험코드: 647800740
#
# [15/20] 🔍 https://terms.naver.com/entry.naver?docId=2126899&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2126899&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114095004864_9USTB5D20.jpg%2F201103159.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114095004864_9USTB5D20.jpg/201103159.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 13개)
#       📋 약품명: 모티리톤정
#       📋 업체명: 동아에스티(주)
#       📋 보험코드: 642506570
#
# [16/20] 🔍 https://terms.naver.com/entry.naver?docId=2133029&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2133029&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114061432726_4031TQTGR.jpg%2F196500004.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114061432726_4031TQTGR.jpg/196500004.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 14개)
#       📋 약품명: 후라시닐정(메트로니다졸)
#       📋 업체명: 에이치케이이노엔(주)
#       📋 보험코드: 640002760
#
# [17/20] 🔍 https://terms.naver.com/entry.naver?docId=2144900&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2144900&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114071502551_CSYLGMEG3.jpg%2F200000601.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114071502551_CSYLGMEG3.jpg/200000601.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 15개)
#       📋 약품명: 고덱스캡슐
#       📋 업체명: (주)셀트리온제약
#       📋 보험코드: 693900080
#
# [18/20] 🔍 https://terms.naver.com/entry.naver?docId=2140285&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2140285&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_42%2F20231222223504160_DSJ224Q7N.jpg%2F199602982.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_42/20231222223504160_DSJ224Q7N.jpg/199602982.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 16개)
#       📋 약품명: 소론도정(프레드니솔론)
#       📋 업체명: (주)유한양행
#       📋 보험코드: 642105020
#
# [19/20] 🔍 https://terms.naver.com/entry.naver?docId=2142423&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=2142423&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114083828832_NZFZ44I3J.jpg%2F200700634.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114083828832_NZFZ44I3J.jpg/200700634.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 17개)
#       📋 약품명: 스틸녹스정10mg(졸피뎀타르타르산염)
#       📋 업체명: (주)한독
#       📋 보험코드: 652100640
#
# [20/20] 🔍 https://terms.naver.com/entry.naver?docId=6638486&cid=51000&categoryId=51000
#     구분: 전문의약품
#   ✅ 전문의약품 확인! 상세 정보 수집 중...
#       🔍 이미지 URL 추출 시도...
#       ✓ a 태그 찾음
#       ✓ href 값: /imageDetail.naver?docId=6638486&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F3323_000_35%2F20231114175238854_YFMQL89KX.jpg%2F202204039.jpg%3Ftype%3Dm4500_4500_fst_n%26wm%3DY
#       ✓ imageUrl 파라미터 존재
#       ✓ 파싱된 파라미터: ['docId', 'imageUrl']
#       ✅ 이미지 URL 추출 성공!
#       📷 URL: https://dbscthumb-phinf.pstatic.net/3323_000_35/20231114175238854_YFMQL89KX.jpg/202204039.jpg?type=m...
#   ✅ 수집 완료 (전문의약품 총 18개)
#       📋 약품명: 아리피졸정1mg(아리피프라졸)
#       📋 업체명: 환인제약(주)
#       📋 보험코드: 657203970
#
# ============================================================
# ✅ 테스트 완료! 결과 저장 중...
# ============================================================
#
# ✅ 테스트 데이터 저장: test_professional_medicines_20251129_173755.csv (18건)
#
# ============================================================
# 📊 테스트 통계
# ============================================================
# 테스트 URL 수: 20건
# 전문의약품: 18건
# 일반의약품 등 (스킵): 2건
# 크롤링 실패: 0건
# ============================================================
#
# 📋 수집된 데이터 미리보기:
#                    약품명     구분          업체명       보험코드
# 0         펠루비정(펠루비프로펜)  전문의약품      대원제약(주)  671803380
# 1     슈다페드정(슈도에페드린염산염)  전문의약품      삼일제약(주)  643900710
# 2  인데놀정10mg(프로프라놀롤염산염)  전문의약품      동광제약(주)  645902470
# 3       바난정(세프포독심프록세틸)  전문의약품  에이치케이이노엔(주)  640000480
# 4                 코데날정  전문의약품      삼아제약(주)  645701150
# 5         낙소졸정500/20mg  전문의약품      한미약품(주)  643506630
# 6       펠루비서방정(펠루비프로펜)  전문의약품      대원제약(주)  671805860
# 7     리리카캡슐25mg(프레가발린)  전문의약품  비아트리스코리아(주)  073400230
# 8  글리아타민연질캡슐(콜린알포세레이트)  전문의약품     대웅바이오(주)  694000600
# 9     알프람정0.5mg(알프라졸람)  전문의약품      환인제약(주)  657200490
#
# 📋 수집된 전체 컬럼 (21개):
# ['url', 'doc_id', '약품명', '이미지_URL', '분류', '구분', '업체명', '보험코드', '성상', '제형', '모양', '색깔', '크기', '식별표기', '성분정보', '효능효과', '용법용량', '저장방법', '사용기간', '사용상의주의사항', '분할선']
#
# ⏱️  총 소요 시간: 2.96분 (177.48초)
#
# ✅ 테스트 완료! 문제없으면 전체 크롤링 코드를 실행하세요.

# %%
df_test30 = pd.read_csv("test_professional_medicines_20251129_173755.csv")

# %%
df_test30.head()
# Out:
#                                                  url   doc_id  \
# 0  https://terms.naver.com/entry.naver?docId=2146...  2146611
# 1  https://terms.naver.com/entry.naver?docId=2134...  2134728
# 2  https://terms.naver.com/entry.naver?docId=2141...  2141123
# 3  https://terms.naver.com/entry.naver?docId=2133...  2133054
# 4  https://terms.naver.com/entry.naver?docId=2140...  2140794
#
#                    약품명                                            이미지_URL  \
# 0         펠루비정(펠루비프로펜)  https://dbscthumb-phinf.pstatic.net/3323_000_3...
# 1     슈다페드정(슈도에페드린염산염)  https://dbscthumb-phinf.pstatic.net/3323_000_4...
# 2  인데놀정10mg(프로프라놀롤염산염)  https://dbscthumb-phinf.pstatic.net/3323_000_3...
# 3       바난정(세프포독심프록세틸)  https://dbscthumb-phinf.pstatic.net/3323_000_3...
# 4                 코데날정  https://dbscthumb-phinf.pstatic.net/3323_000_3...
#
#                             분류     구분          업체명       보험코드  \
# 0             [01140]해열.진통.소염제  전문의약품      대원제약(주)  671803380
# 1            [02290]기타의 호흡기관용약  전문의약품      삼일제약(주)  643900710
# 2                 [02120]부정맥용제  전문의약품      동광제약(주)  645902470
# 3  [06180]주로 그람양성, 음성균에 작용하는 것  전문의약품  에이치케이이노엔(주)  640000480
# 4                 [02220]진해거담제  전문의약품      삼아제약(주)  645701150
#
#                                 성상     제형  ...  색깔  \
# 0                         담황색 원형정제     나정  ...  노랑
# 1                        흰색의 원형 정제     나정  ...  하양
# 2                           백색의 정제     나정  ...  하양
# 3               흰색-연한노란색의 원형 필름코팅정  필름코팅정  ...  하양
# 4  (내수용) 흰색의 원형 정제(수출용) 미황색의 원형 정제     나정  ...  하양
#
#                             크기                                  식별표기  \
# 0        (장축)7, (단축)7, (두께)2.2                                마크, PE
# 1      (장축)8.5, (단축)8.5, (두께)3  마크분할선SD분할선마크분할선SD, 마크분할선SD분할선마크분할선SD
# 2    (장축)7.0, (단축)7.0, (두께)2.0                                DK, 10
# 3    (장축)8.7, (단축)8.7, (두께)4.5                                   BNT
# 4  (장축)10.1, (단축)10.1, (두께)3.4                               마크, 분할선
#
#                                                 성분정보  \
# 0                     이 약 1정(110mg) 중\n펠루비프로펜 30.0mg
# 1                        1정(235mg) 중\n슈도에페드린염산염 60mg
# 2                         1정 중 100mg\n프로프라놀롤염산염 10mg
# 3                   이 약 1정(230mg) 중\n세프포독심프록세틸 100mg
# 4  1정 (349.47mg) 중-[내수용]\n디히드로코데인타르타르산염 5.0mg, 구아...
#
#                                                 효능효과  \
# 0  1. 다음 질환의 증상이나 징후의 완화 : 골관절염, 류마티스관절염, 요통(허리통증...
# 1              다음 질환에 의한 비충혈 완화 : 감기, 부비동염, 상기도 알레르기
# 2  1. 기외수축(상실성, 심실성), 발작성빈맥의 예방, 빈맥성심방세동, 발작성심방세동...
# 3  (정제)\n○ 유효균종\n포도구균, 연쇄구균, 폐렴연쇄구균, 임균, 펩토연쇄구균, ...
# 4                                             기침, 가래
#
#                                                 용법용량  \
# 0      성인 : 1회 1정(펠루비프로펜으로서 30mg), 1일 3회 식후 경구 투여한다.
# 1  ○ 성인 및 12세 이상 : 수도에페드린염산염으로서 1회 30 ～ 60 mg 1일 ...
# 2  1. 기외수축(상실성, 심실성), 발작성빈맥의 예방, 빈맥성심방세동, 발작성심방세동...
# 3  (정제)\n○ 성인 : 세프포독심으로서 1회 100mg(역가)을 1일 2회 식후 경...
# 4  1. 성인 및 15세 이상 청소년 : 1회 2정씩 1일 3회 식후 경구투여한다.\n...
#
#                                      저장방법          사용기간  \
# 0                     차광기밀용기, 실온보관(1-30℃)  제조일로부터 36 개월
# 1  기밀용기 또는 밀폐용기, 실온(1~30℃)보관, 제조일로부터 36개월  제조일로부터 36 개월
# 2                                  차광밀폐용기  제조일로부터 60 개월
# 3                              기밀용기, 실온보존  제조일로부터 36 개월
# 4                       기밀용기, 실온(1∼30℃)보관  제조일로부터 36 개월
#
#                                             사용상의주의사항   분할선
# 0  1. 경고\n(1) 매일 세잔 이상 정기적으로 술을 마시는 사람이 이 약이나 다른 ...   NaN
# 1  1. 경고\n슈도에페드린 함유 의약품 복용시 급성 전신성 발진성 농포증(AGEP)과...  +, +
# 2  1. 다음 환자에는 투여하지 말 것.\n1) 이 약에 과민반응 환자\n2) 만성 폐...   NaN
# 3  1. 다음 환자에는 투여하지 말 것.\n이 약에 의한 쇽의 병력이 있는 환자\n\n...   NaN
# 4  1. 경고\n중증의 호흡 억제 위험이 증가할 수 있으니 18세 미만의 비만, 폐색성...     -
#
# [5 rows x 21 columns]

# %%
df_test30.columns
# Out:
# Index(['url', 'doc_id', '약품명', '이미지_URL', '분류', '구분', '업체명', '보험코드', '성상',
#        '제형', '모양', '색깔', '크기', '식별표기', '성분정보', '효능효과', '용법용량', '저장방법', '사용기간',
#        '사용상의주의사항', '분할선'],
#       dtype='object')

# %%
df_test30["사용기간"]
# Out:
# 0                               제조일로부터 36 개월
# 1                               제조일로부터 36 개월
# 2                               제조일로부터 60 개월
# 3                               제조일로부터 36 개월
# 4                               제조일로부터 36 개월
# 5                               제조일로부터 24 개월
# 6                               제조일로부터 36 개월
# 7                               제조일로부터 36 개월
# 8                               제조일로부터 24 개월
# 9                               제조일로부터 36 개월
# 10                              제조일로부터 36 개월
# 11                              제조일로부터 36 개월
# 12                              제조일로부터 24 개월
# 13                              제조일로부터 60 개월
# 14    제조일로부터 36 개월,제조일로부터 36 개월,제조일로부터 24 개월
# 15                              제조일로부터 36 개월
# 16                              제조일로부터 48 개월
# 17                              제조일로부터 36 개월
# Name: 사용기간, dtype: object

# %%
df_test30.iloc[14]
# Out:
# url         https://terms.naver.com/entry.naver?docId=2144...
# doc_id                                                2144900
# 약품명                                                     고덱스캡슐
# 이미지_URL     https://dbscthumb-phinf.pstatic.net/3323_000_3...
# 분류                                              [03910]간장질환용제
# 구분                                                      전문의약품
# 업체명                                                 (주)셀트리온제약
# 보험코드                                                693900080
# 성상                          황갈색의 분말이 들어있는 상 ·하 적갈색 불투명의 경질캡슐제
# 제형                                                  경질캡슐제, 산제
# 모양                                                        장방형
# 색깔                                                     갈색, 갈색
# 크기                              (장축)19.10, (단축)6.63, (두께)6.91
# 식별표기                                                  GODEX마크
# 성분정보        1캡슐(412mg) 중\n오로트산카르니틴 150mg, 항독성간장엑스 12.5mg, ...
# 효능효과                                   트란스아미나제(SGPT)가 상승된 간질환
# 용법용량             성인 1회 2캡슐, 1일 2-3회 복용한다. 연령, 증상에 따라 적의 증감한다.
# 저장방법                                        기밀용기, 실온보관(1-30℃)
# 사용기간                   제조일로부터 36 개월,제조일로부터 36 개월,제조일로부터 24 개월
# 사용상의주의사항    1. 다음 환자는 투여하지 말 것\n1) 이 약 및 이 약에 포함된 성분에 과민반응...
# 분할선                                                       NaN
# Name: 14, dtype: object

# %% [markdown]
# ## 진짜 코드 !!

# %% [markdown]
# ```
# 📋 주요 기능
# 1. ✅ 이미지 URL 수정
#
# 테스트 코드와 동일한 방식으로 <a> 태그의 imageUrl 파라미터에서 추출
#
# 2. ✅ data 폴더에 저장
#
# data/ 폴더 자동 생성
# 모든 CSV 파일은 data/ 안에 저장
#
# 3. ✅ 개수별 파일명
#
# data/200개_01.csv
# data/200개_02.csv
# data/147개_05.csv (마지막 배치가 147개인 경우)
#
# 4. ✅ 중단/재개 기능
# 저장되는 파일들:
#
# all_medicine_urls.json - 전체 URL 목록 (처음 한 번만 수집)
# crawling_progress.json - 진행 상황 (매번 업데이트)
#
# 재개 방법:
#
# 크롤링 중 중단됨
# 다시 실행하면 "이어서 하시겠습니까?" 물어봄
# y 입력하면 중단된 지점부터 재개
# n 입력하면 처음부터 새로 시작
# ```

# %%
"""
네이버 의약품 백과사전 전문의약품 크롤링 - 전체 버전
- 전체 의약품 중 전문의약품만 크롤링
- 중단/재개 기능 포함
- 200개씩 data 폴더에 저장
"""

import asyncio
from playwright.async_api import async_playwright
import pandas as pd
from datetime import datetime
import json
import time
import os
import urllib.parse

# 주피터 노트북용 이벤트 루프 설정
import nest_asyncio
nest_asyncio.apply()

# data 폴더 생성
os.makedirs('data', exist_ok=True)

# 진행 상황 파일 경로
PROGRESS_FILE = 'crawling_progress.json'
ALL_URLS_FILE = 'all_medicine_urls.json'


def save_progress(current_index, total_processed, total_professional):
    """크롤링 진행 상황 저장"""
    progress = {
        'current_index': current_index,
        'total_processed': total_processed,
        'total_professional': total_professional,
        'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    }
    with open(PROGRESS_FILE, 'w', encoding='utf-8') as f:
        json.dump(progress, f, ensure_ascii=False, indent=2)


def load_progress():
    """저장된 진행 상황 불러오기"""
    if os.path.exists(PROGRESS_FILE):
        with open(PROGRESS_FILE, 'r', encoding='utf-8') as f:
            return json.load(f)
    return None


def save_batch(medicines, batch_number):
    """200개씩 배치 저장"""
    count = len(medicines)
    filename = f'data/{count}개_{batch_number:02d}.csv'
    
    df = pd.DataFrame(medicines)
    df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"\n💾 배치 저장: {filename} ({count}건)")
    return filename


async def get_medicine_classification(page, url, max_retries=3):
    """약품 상세 페이지에서 '구분' 확인 (전문의약품이면 True)"""
    for attempt in range(max_retries):
        try:
            await page.goto(url, wait_until='networkidle', timeout=30000)
            await asyncio.sleep(2)
            
            # 테이블에서 '구분' 찾기
            rows = await page.locator('table.tmp_profile_tb tr').all()
            
            for row in rows:
                th_text = await row.locator('th').inner_text()
                if '구분' in th_text:
                    td_text = await row.locator('td').inner_text()
                    classification = td_text.strip()
                    return classification == '전문의약품'
            
            return False
            
        except Exception as e:
            if attempt < max_retries - 1:
                await asyncio.sleep(3)
            else:
                return False


async def scrape_medicine_detail(page, url, max_retries=3):
    """개별 의약품 상세 정보 크롤링"""
    for attempt in range(max_retries):
        try:
            await page.goto(url, wait_until='networkidle', timeout=30000)
            await asyncio.sleep(2)
            
            medicine_data = {
                'url': url,
                'doc_id': url.split('docId=')[1].split('&')[0] if 'docId=' in url else None
            }
            
            # 약품명
            try:
                title = await page.locator('h2.headword').inner_text()
                medicine_data['약품명'] = title.strip()
            except:
                medicine_data['약품명'] = None
            
            # 이미지 URL 추출 (a 태그의 href에서 imageUrl 파라미터 추출)
            try:
                img_link = page.locator('span.img_box > a').first
                count = await img_link.count()
                
                if count > 0:
                    href = await img_link.get_attribute('href')
                    
                    if href and 'imageUrl=' in href:
                        parsed = urllib.parse.urlparse(href)
                        params = urllib.parse.parse_qs(parsed.query)
                        
                        if 'imageUrl' in params:
                            medicine_data['이미지_URL'] = params['imageUrl'][0]
                        else:
                            medicine_data['이미지_URL'] = None
                    else:
                        medicine_data['이미지_URL'] = None
                else:
                    medicine_data['이미지_URL'] = None
            except:
                medicine_data['이미지_URL'] = None
            
            # 테이블 정보 추출
            try:
                rows = await page.locator('table.tmp_profile_tb tr').all()
                
                for row in rows:
                    th_text = await row.locator('th').inner_text()
                    td_text = await row.locator('td').inner_text()
                    medicine_data[th_text.strip()] = td_text.strip()
            except:
                pass
            
            # 성분정보
            try:
                content1 = await page.locator('#TABLE_OF_CONTENT1').locator('xpath=following-sibling::p[@class="txt"]').first.inner_text()
                medicine_data['성분정보'] = content1.strip()
            except:
                medicine_data['성분정보'] = None
            
            # 효능효과
            try:
                content2 = await page.locator('#TABLE_OF_CONTENT2').locator('xpath=following-sibling::p[@class="txt"]').first.inner_text()
                medicine_data['효능효과'] = content2.strip()
            except:
                medicine_data['효능효과'] = None
            
            # 용법용량
            try:
                content3 = await page.locator('#TABLE_OF_CONTENT3').locator('xpath=following-sibling::p[@class="txt"]').first.inner_text()
                medicine_data['용법용량'] = content3.strip()
            except:
                medicine_data['용법용량'] = None
            
            # 저장방법
            try:
                content4 = await page.locator('#TABLE_OF_CONTENT4').locator('xpath=following-sibling::p[@class="txt"]').first.inner_text()
                medicine_data['저장방법'] = content4.strip()
            except:
                medicine_data['저장방법'] = None
            
            # 사용기간
            try:
                content5 = await page.locator('#TABLE_OF_CONTENT5').locator('xpath=following-sibling::p[@class="txt"]').first.inner_text()
                medicine_data['사용기간'] = content5.strip()
            except:
                medicine_data['사용기간'] = None
            
            # 사용상의주의사항
            try:
                content6 = await page.locator('#TABLE_OF_CONTENT6').locator('xpath=following-sibling::p[@class="txt"]').first.inner_text()
                medicine_data['사용상의주의사항'] = content6.strip()
            except:
                medicine_data['사용상의주의사항'] = None
            
            return medicine_data
            
        except Exception as e:
            if attempt < max_retries - 1:
                await asyncio.sleep(3)
            else:
                return None


async def get_all_medicine_urls(page, base_url):
    """전체 의약품 URL 목록 수집"""
    all_urls = []
    page_num = 1
    
    while True:
        print(f"\n📄 페이지 {page_num} URL 수집 중...")
        
        current_url = f"{base_url}&page={page_num}"
        
        try:
            await page.goto(current_url, wait_until='networkidle', timeout=30000)
            await asyncio.sleep(2)
            
            # 현재 페이지의 모든 약품 링크 수집
            links = await page.locator('ul.content_list li a[href*="entry.naver"]').all()
            
            if not links:
                print(f"✓ 페이지 {page_num}에서 더 이상 링크를 찾을 수 없습니다.")
                break
            
            page_urls = []
            for link in links:
                href = await link.get_attribute('href')
                if href and 'entry.naver' in href:
                    full_url = f"https://terms.naver.com{href}" if href.startswith('/') else href
                    if full_url not in page_urls:
                        page_urls.append(full_url)
            
            all_urls.extend(page_urls)
            print(f"  ✓ {len(page_urls)}개 URL 수집 (누적: {len(all_urls)}개)")
            
            # 다음 페이지 버튼 확인
            try:
                next_button = page.locator('span.next a')
                if await next_button.count() == 0:
                    print("✓ 마지막 페이지 도달!")
                    break
            except:
                print("✓ 마지막 페이지 도달!")
                break
            
            page_num += 1
            await asyncio.sleep(1.5)
            
        except Exception as e:
            print(f"⚠️ 페이지 {page_num} 처리 중 오류: {e}")
            break
    
    return all_urls


async def main():
    """메인 크롤링 함수"""
    
    base_url = "https://terms.naver.com/medicineSearch.naver?mode=exteriorSearch&shape=&color=&dosageForm=&divisionLine=&identifier="
    
    professional_medicines = []
    current_batch = []
    batch_number = 1
    failed_urls = []
    skipped_count = 0
    
    # 진행 상황 확인
    progress = load_progress()
    start_index = 0
    
    if progress:
        print(f"\n🔄 이전 크롤링 진행 상황 발견!")
        print(f"  - 마지막 처리 인덱스: {progress['current_index']}")
        print(f"  - 처리된 총 개수: {progress['total_processed']}")
        print(f"  - 수집된 전문의약품: {progress['total_professional']}")
        print(f"  - 저장 시각: {progress['timestamp']}")
        
        resume = input("\n이어서 크롤링하시겠습니까? (y/n): ")
        if resume.lower() == 'y':
            start_index = progress['current_index'] + 1
            batch_number = (progress['total_professional'] // 200) + 1
            print(f"✅ 인덱스 {start_index}부터 재개합니다.\n")
        else:
            print("✅ 처음부터 새로 시작합니다.\n")
            start_index = 0
    
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False)
        context = await browser.new_context()
        page = await context.new_page()
        
        # 1단계: URL 수집 또는 불러오기
        if os.path.exists(ALL_URLS_FILE) and start_index > 0:
            print("=" * 60)
            print("📂 저장된 URL 목록 불러오는 중...")
            print("=" * 60)
            
            with open(ALL_URLS_FILE, 'r', encoding='utf-8') as f:
                all_urls = json.load(f)
            print(f"✅ {len(all_urls)}개의 URL 불러오기 완료!\n")
        else:
            print("=" * 60)
            print("🔍 1단계: 전체 의약품 URL 수집 중...")
            print("=" * 60)
            
            all_urls = await get_all_medicine_urls(page, base_url)
            print(f"\n✅ 총 {len(all_urls)}개의 URL 수집 완료!\n")
            
            # URL 저장
            with open(ALL_URLS_FILE, 'w', encoding='utf-8') as f:
                json.dump(all_urls, f, ensure_ascii=False, indent=2)
            print(f"✅ URL 목록 저장: {ALL_URLS_FILE}\n")
        
        # 2단계: 크롤링
        print("=" * 60)
        print("🔍 2단계: 전문의약품 크롤링 시작...")
        print("=" * 60)
        
        total_professional = progress['total_professional'] if progress and start_index > 0 else 0
        
        for idx in range(start_index, len(all_urls)):
            url = all_urls[idx]
            print(f"\n[{idx + 1}/{len(all_urls)}] 🔍 처리 중...")
            
            # 구분 확인
            is_professional = await get_medicine_classification(page, url)
            
            if not is_professional:
                skipped_count += 1
                if (idx + 1) % 10 == 0:
                    print(f"  ⏭️  스킵 (총 스킵: {skipped_count}개)")
                await asyncio.sleep(1)
                
                # 진행 상황 저장
                save_progress(idx, idx + 1 - start_index, total_professional)
                continue
            
            # 전문의약품 크롤링
            medicine_data = await scrape_medicine_detail(page, url)
            
            if medicine_data:
                current_batch.append(medicine_data)
                total_professional += 1
                print(f"  ✅ 전문의약품 수집 완료 (배치: {len(current_batch)}/200, 총: {total_professional}개)")
                
                # 200개마다 저장
                if len(current_batch) >= 200:
                    save_batch(current_batch, batch_number)
                    batch_number += 1
                    current_batch = []
            else:
                failed_urls.append(url)
                print(f"  ❌ 수집 실패")
            
            # 진행 상황 저장 (매번)
            save_progress(idx, idx + 1 - start_index, total_professional)
            
            await asyncio.sleep(2)
        
        # 남은 데이터 저장
        if current_batch:
            save_batch(current_batch, batch_number)
        
        await browser.close()
    
    # 최종 결과
    print("\n" + "=" * 60)
    print("✅ 크롤링 완료!")
    print("=" * 60)
    
    # 실패 목록 저장
    if failed_urls:
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        with open(f'failed_urls_{timestamp}.json', 'w', encoding='utf-8') as f:
            json.dump(failed_urls, f, ensure_ascii=False, indent=2)
        print(f"⚠️  실패한 URL: failed_urls_{timestamp}.json ({len(failed_urls)}건)")
    
    # 통계
    print(f"\n전체 약품 수: {len(all_urls)}건")
    print(f"전문의약품: {total_professional}건")
    print(f"일반의약품 등 (스킵): {skipped_count}건")
    print(f"크롤링 실패: {len(failed_urls)}건")
    print(f"저장된 배치 파일: {batch_number}개")
    print("=" * 60)
    
    # 진행 상황 파일 삭제 (완료되었으므로)
    if os.path.exists(PROGRESS_FILE):
        os.remove(PROGRESS_FILE)
        print("✅ 진행 상황 파일 삭제 완료")
    
    return total_professional


# 실행
print("🚀 네이버 의약품 백과사전 전문의약품 크롤링 시작!\n")
start_time = time.time()

total_count = await main()

end_time = time.time()
elapsed_time = end_time - start_time
print(f"\n⏱️  총 소요 시간: {elapsed_time/3600:.2f}시간 ({elapsed_time/60:.2f}분)")
print(f"✅ 총 {total_count}개의 전문의약품 수집 완료!")
# Out:
# 🚀 네이버 의약품 백과사전 전문의약품 크롤링 시작!
#
#
# 🔄 이전 크롤링 진행 상황 발견!
#   - 마지막 처리 인덱스: 28
#   - 처리된 총 개수: 29
#   - 수집된 전문의약품: 5
#   - 저장 시각: 2025-11-30 01:09:23
# 이어서 크롤링하시겠습니까? (y/n):  n
# ✅ 처음부터 새로 시작합니다.
#
# ============================================================
# 🔍 1단계: 전체 의약품 URL 수집 중...
# ============================================================
#
# 📄 페이지 1 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 15개)
#
# 📄 페이지 2 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 30개)
#
# 📄 페이지 3 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 45개)
#
# 📄 페이지 4 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 60개)
#
# 📄 페이지 5 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 75개)
#
# 📄 페이지 6 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 90개)
#
# 📄 페이지 7 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 105개)
#
# 📄 페이지 8 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 120개)
#
# 📄 페이지 9 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 135개)
#
# 📄 페이지 10 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 150개)
#
# 📄 페이지 11 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 165개)
#
# 📄 페이지 12 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 180개)
#
# 📄 페이지 13 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 195개)
#
# 📄 페이지 14 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 210개)
#
# 📄 페이지 15 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 225개)
#
# 📄 페이지 16 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 240개)
#
# 📄 페이지 17 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 255개)
#
# 📄 페이지 18 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 270개)
#
# 📄 페이지 19 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 285개)
#
# 📄 페이지 20 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 300개)
#
# 📄 페이지 21 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 315개)
#
# 📄 페이지 22 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 330개)
#
# 📄 페이지 23 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 345개)
#
# 📄 페이지 24 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 360개)
#
# 📄 페이지 25 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 375개)
#
# 📄 페이지 26 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 390개)
#
# 📄 페이지 27 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 405개)
#
# 📄 페이지 28 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 420개)
#
# 📄 페이지 29 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 435개)
#
# 📄 페이지 30 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 450개)
#
# 📄 페이지 31 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 465개)
#
# 📄 페이지 32 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 480개)
#
# 📄 페이지 33 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 495개)
#
# 📄 페이지 34 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 510개)
#
# 📄 페이지 35 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 525개)
#
# 📄 페이지 36 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 540개)
#
# 📄 페이지 37 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 555개)
#
# 📄 페이지 38 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 570개)
#
# 📄 페이지 39 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 585개)
#
# 📄 페이지 40 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 600개)
#
# 📄 페이지 41 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 615개)
#
# 📄 페이지 42 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 630개)
#
# 📄 페이지 43 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 645개)
#
# 📄 페이지 44 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 660개)
#
# 📄 페이지 45 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 675개)
#
# 📄 페이지 46 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 690개)
#
# 📄 페이지 47 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 705개)
#
# 📄 페이지 48 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 720개)
#
# 📄 페이지 49 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 735개)
#
# 📄 페이지 50 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 750개)
#
# 📄 페이지 51 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 765개)
#
# 📄 페이지 52 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 780개)
#
# 📄 페이지 53 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 795개)
#
# 📄 페이지 54 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 810개)
#
# 📄 페이지 55 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 825개)
#
# 📄 페이지 56 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 840개)
#
# 📄 페이지 57 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 855개)
#
# 📄 페이지 58 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 870개)
#
# 📄 페이지 59 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 885개)
#
# 📄 페이지 60 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 900개)
#
# 📄 페이지 61 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 915개)
#
# 📄 페이지 62 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 930개)
#
# 📄 페이지 63 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 945개)
#
# 📄 페이지 64 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 960개)
#
# 📄 페이지 65 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 975개)
#
# 📄 페이지 66 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 990개)
#
# 📄 페이지 67 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1005개)
#
# 📄 페이지 68 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1020개)
#
# 📄 페이지 69 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1035개)
#
# 📄 페이지 70 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1050개)
#
# 📄 페이지 71 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1065개)
#
# 📄 페이지 72 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1080개)
#
# 📄 페이지 73 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1095개)
#
# 📄 페이지 74 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1110개)
#
# 📄 페이지 75 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1125개)
#
# 📄 페이지 76 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1140개)
#
# 📄 페이지 77 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1155개)
#
# 📄 페이지 78 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1170개)
#
# 📄 페이지 79 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1185개)
#
# 📄 페이지 80 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1200개)
#
# 📄 페이지 81 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1215개)
#
# 📄 페이지 82 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1230개)
#
# 📄 페이지 83 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1245개)
#
# 📄 페이지 84 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1260개)
#
# 📄 페이지 85 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1275개)
#
# 📄 페이지 86 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1290개)
#
# 📄 페이지 87 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1305개)
#
# 📄 페이지 88 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1320개)
#
# 📄 페이지 89 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1335개)
#
# 📄 페이지 90 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1350개)
#
# 📄 페이지 91 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1365개)
#
# 📄 페이지 92 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1380개)
#
# 📄 페이지 93 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1395개)
#
# 📄 페이지 94 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1410개)
#
# 📄 페이지 95 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1425개)
#
# 📄 페이지 96 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1440개)
#
# 📄 페이지 97 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1455개)
#
# 📄 페이지 98 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1470개)
#
# 📄 페이지 99 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1485개)
#
# 📄 페이지 100 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1500개)
#
# 📄 페이지 101 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1515개)
#
# 📄 페이지 102 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1530개)
#
# 📄 페이지 103 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1545개)
#
# 📄 페이지 104 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1560개)
#
# 📄 페이지 105 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1575개)
#
# 📄 페이지 106 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1590개)
#
# 📄 페이지 107 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1605개)
#
# 📄 페이지 108 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1620개)
#
# 📄 페이지 109 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1635개)
#
# 📄 페이지 110 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1650개)
#
# 📄 페이지 111 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1665개)
#
# 📄 페이지 112 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1680개)
#
# 📄 페이지 113 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1695개)
#
# 📄 페이지 114 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1710개)
#
# 📄 페이지 115 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1725개)
#
# 📄 페이지 116 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1740개)
#
# 📄 페이지 117 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1755개)
#
# 📄 페이지 118 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1770개)
#
# 📄 페이지 119 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1785개)
#
# 📄 페이지 120 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1800개)
#
# 📄 페이지 121 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1815개)
#
# 📄 페이지 122 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1830개)
#
# 📄 페이지 123 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1845개)
#
# 📄 페이지 124 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1860개)
#
# 📄 페이지 125 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1875개)
#
# 📄 페이지 126 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1890개)
#
# 📄 페이지 127 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1905개)
#
# 📄 페이지 128 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1920개)
#
# 📄 페이지 129 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1935개)
#
# 📄 페이지 130 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1950개)
#
# 📄 페이지 131 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1965개)
#
# 📄 페이지 132 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1980개)
#
# 📄 페이지 133 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 1995개)
#
# 📄 페이지 134 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2010개)
#
# 📄 페이지 135 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2025개)
#
# 📄 페이지 136 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2040개)
#
# 📄 페이지 137 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2055개)
#
# 📄 페이지 138 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2070개)
#
# 📄 페이지 139 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2085개)
#
# 📄 페이지 140 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2100개)
#
# 📄 페이지 141 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2115개)
#
# 📄 페이지 142 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2130개)
#
# 📄 페이지 143 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2145개)
#
# 📄 페이지 144 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2160개)
#
# 📄 페이지 145 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2175개)
#
# 📄 페이지 146 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2190개)
#
# 📄 페이지 147 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2205개)
#
# 📄 페이지 148 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2220개)
#
# 📄 페이지 149 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2235개)
#
# 📄 페이지 150 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2250개)
#
# 📄 페이지 151 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2265개)
#
# 📄 페이지 152 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2280개)
#
# 📄 페이지 153 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2295개)
#
# 📄 페이지 154 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2310개)
#
# 📄 페이지 155 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2325개)
#
# 📄 페이지 156 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2340개)
#
# 📄 페이지 157 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2355개)
#
# 📄 페이지 158 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2370개)
#
# 📄 페이지 159 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2385개)
#
# 📄 페이지 160 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2400개)
#
# 📄 페이지 161 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2415개)
#
# 📄 페이지 162 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2430개)
#
# 📄 페이지 163 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2445개)
#
# 📄 페이지 164 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2460개)
#
# 📄 페이지 165 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2475개)
#
# 📄 페이지 166 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2490개)
#
# 📄 페이지 167 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2505개)
#
# 📄 페이지 168 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2520개)
#
# 📄 페이지 169 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2535개)
#
# 📄 페이지 170 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2550개)
#
# 📄 페이지 171 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2565개)
#
# 📄 페이지 172 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2580개)
#
# 📄 페이지 173 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2595개)
#
# 📄 페이지 174 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2610개)
#
# 📄 페이지 175 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2625개)
#
# 📄 페이지 176 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2640개)
#
# 📄 페이지 177 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2655개)
#
# 📄 페이지 178 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2670개)
#
# 📄 페이지 179 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2685개)
#
# 📄 페이지 180 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2700개)
#
# 📄 페이지 181 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2715개)
#
# 📄 페이지 182 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2730개)
#
# 📄 페이지 183 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2745개)
#
# 📄 페이지 184 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2760개)
#
# 📄 페이지 185 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2775개)
#
# 📄 페이지 186 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2790개)
#
# 📄 페이지 187 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2805개)
#
# 📄 페이지 188 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2820개)
#
# 📄 페이지 189 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2835개)
#
# 📄 페이지 190 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2850개)
#
# 📄 페이지 191 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2865개)
#
# 📄 페이지 192 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2880개)
#
# 📄 페이지 193 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2895개)
#
# 📄 페이지 194 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2910개)
#
# 📄 페이지 195 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2925개)
#
# 📄 페이지 196 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2940개)
#
# 📄 페이지 197 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2955개)
#
# 📄 페이지 198 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2970개)
#
# 📄 페이지 199 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 2985개)
#
# 📄 페이지 200 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3000개)
#
# 📄 페이지 201 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3015개)
#
# 📄 페이지 202 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3030개)
#
# 📄 페이지 203 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3045개)
#
# 📄 페이지 204 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3060개)
#
# 📄 페이지 205 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3075개)
#
# 📄 페이지 206 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3090개)
#
# 📄 페이지 207 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3105개)
#
# 📄 페이지 208 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3120개)
#
# 📄 페이지 209 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3135개)
#
# 📄 페이지 210 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3150개)
#
# 📄 페이지 211 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3165개)
#
# 📄 페이지 212 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3180개)
#
# 📄 페이지 213 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3195개)
#
# 📄 페이지 214 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3210개)
#
# 📄 페이지 215 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3225개)
#
# 📄 페이지 216 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3240개)
#
# 📄 페이지 217 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3255개)
#
# 📄 페이지 218 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3270개)
#
# 📄 페이지 219 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3285개)
#
# 📄 페이지 220 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3300개)
#
# 📄 페이지 221 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3315개)
#
# 📄 페이지 222 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3330개)
#
# 📄 페이지 223 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3345개)
#
# 📄 페이지 224 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3360개)
#
# 📄 페이지 225 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3375개)
#
# 📄 페이지 226 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3390개)
#
# 📄 페이지 227 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3405개)
#
# 📄 페이지 228 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3420개)
#
# 📄 페이지 229 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3435개)
#
# 📄 페이지 230 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3450개)
#
# 📄 페이지 231 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3465개)
#
# 📄 페이지 232 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3480개)
#
# 📄 페이지 233 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3495개)
#
# 📄 페이지 234 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3510개)
#
# 📄 페이지 235 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3525개)
#
# 📄 페이지 236 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3540개)
#
# 📄 페이지 237 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3555개)
#
# 📄 페이지 238 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3570개)
#
# 📄 페이지 239 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3585개)
#
# 📄 페이지 240 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3600개)
#
# 📄 페이지 241 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3615개)
#
# 📄 페이지 242 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3630개)
#
# 📄 페이지 243 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3645개)
#
# 📄 페이지 244 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3660개)
#
# 📄 페이지 245 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3675개)
#
# 📄 페이지 246 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3690개)
#
# 📄 페이지 247 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3705개)
#
# 📄 페이지 248 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3720개)
#
# 📄 페이지 249 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3735개)
#
# 📄 페이지 250 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3750개)
#
# 📄 페이지 251 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3765개)
#
# 📄 페이지 252 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3780개)
#
# 📄 페이지 253 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3795개)
#
# 📄 페이지 254 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3810개)
#
# 📄 페이지 255 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3825개)
#
# 📄 페이지 256 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3840개)
#
# 📄 페이지 257 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3855개)
#
# 📄 페이지 258 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3870개)
#
# 📄 페이지 259 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3885개)
#
# 📄 페이지 260 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3900개)
#
# 📄 페이지 261 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3915개)
#
# 📄 페이지 262 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3930개)
#
# 📄 페이지 263 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3945개)
#
# 📄 페이지 264 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3960개)
#
# 📄 페이지 265 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3975개)
#
# 📄 페이지 266 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 3990개)
#
# 📄 페이지 267 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4005개)
#
# 📄 페이지 268 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4020개)
#
# 📄 페이지 269 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4035개)
#
# 📄 페이지 270 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4050개)
#
# 📄 페이지 271 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4065개)
#
# 📄 페이지 272 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4080개)
#
# 📄 페이지 273 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4095개)
#
# 📄 페이지 274 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4110개)
#
# 📄 페이지 275 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4125개)
#
# 📄 페이지 276 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4140개)
#
# 📄 페이지 277 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4155개)
#
# 📄 페이지 278 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4170개)
#
# 📄 페이지 279 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4185개)
#
# 📄 페이지 280 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4200개)
#
# 📄 페이지 281 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4215개)
#
# 📄 페이지 282 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4230개)
#
# 📄 페이지 283 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4245개)
#
# 📄 페이지 284 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4260개)
#
# 📄 페이지 285 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4275개)
#
# 📄 페이지 286 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4290개)
#
# 📄 페이지 287 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4305개)
#
# 📄 페이지 288 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4320개)
#
# 📄 페이지 289 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4335개)
#
# 📄 페이지 290 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4350개)
#
# 📄 페이지 291 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4365개)
#
# 📄 페이지 292 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4380개)
#
# 📄 페이지 293 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4395개)
#
# 📄 페이지 294 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4410개)
#
# 📄 페이지 295 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4425개)
#
# 📄 페이지 296 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4440개)
#
# 📄 페이지 297 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4455개)
#
# 📄 페이지 298 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4470개)
#
# 📄 페이지 299 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4485개)
#
# 📄 페이지 300 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4500개)
#
# 📄 페이지 301 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4515개)
#
# 📄 페이지 302 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4530개)
#
# 📄 페이지 303 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4545개)
#
# 📄 페이지 304 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4560개)
#
# 📄 페이지 305 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4575개)
#
# 📄 페이지 306 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4590개)
#
# 📄 페이지 307 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4605개)
#
# 📄 페이지 308 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4620개)
#
# 📄 페이지 309 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4635개)
#
# 📄 페이지 310 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4650개)
#
# 📄 페이지 311 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4665개)
#
# 📄 페이지 312 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4680개)
#
# 📄 페이지 313 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4695개)
#
# 📄 페이지 314 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4710개)
#
# 📄 페이지 315 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4725개)
#
# 📄 페이지 316 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4740개)
#
# 📄 페이지 317 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4755개)
#
# 📄 페이지 318 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4770개)
#
# 📄 페이지 319 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4785개)
#
# 📄 페이지 320 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4800개)
#
# 📄 페이지 321 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4815개)
#
# 📄 페이지 322 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4830개)
#
# 📄 페이지 323 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4845개)
#
# 📄 페이지 324 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4860개)
#
# 📄 페이지 325 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4875개)
#
# 📄 페이지 326 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4890개)
#
# 📄 페이지 327 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4905개)
#
# 📄 페이지 328 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4920개)
#
# 📄 페이지 329 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4935개)
#
# 📄 페이지 330 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4950개)
#
# 📄 페이지 331 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4965개)
#
# 📄 페이지 332 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4980개)
#
# 📄 페이지 333 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 4995개)
#
# 📄 페이지 334 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5010개)
#
# 📄 페이지 335 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5025개)
#
# 📄 페이지 336 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5040개)
#
# 📄 페이지 337 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5055개)
#
# 📄 페이지 338 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5070개)
#
# 📄 페이지 339 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5085개)
#
# 📄 페이지 340 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5100개)
#
# 📄 페이지 341 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5115개)
#
# 📄 페이지 342 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5130개)
#
# 📄 페이지 343 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5145개)
#
# 📄 페이지 344 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5160개)
#
# 📄 페이지 345 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5175개)
#
# 📄 페이지 346 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5190개)
#
# 📄 페이지 347 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5205개)
#
# 📄 페이지 348 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5220개)
#
# 📄 페이지 349 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5235개)
#
# 📄 페이지 350 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5250개)
#
# 📄 페이지 351 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5265개)
#
# 📄 페이지 352 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5280개)
#
# 📄 페이지 353 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5295개)
#
# 📄 페이지 354 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5310개)
#
# 📄 페이지 355 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5325개)
#
# 📄 페이지 356 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5340개)
#
# 📄 페이지 357 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5355개)
#
# 📄 페이지 358 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5370개)
#
# 📄 페이지 359 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5385개)
#
# 📄 페이지 360 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5400개)
#
# 📄 페이지 361 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5415개)
#
# 📄 페이지 362 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5430개)
#
# 📄 페이지 363 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5445개)
#
# 📄 페이지 364 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5460개)
#
# 📄 페이지 365 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5475개)
#
# 📄 페이지 366 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5490개)
#
# 📄 페이지 367 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5505개)
#
# 📄 페이지 368 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5520개)
#
# 📄 페이지 369 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5535개)
#
# 📄 페이지 370 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5550개)
#
# 📄 페이지 371 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5565개)
#
# 📄 페이지 372 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5580개)
#
# 📄 페이지 373 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5595개)
#
# 📄 페이지 374 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5610개)
#
# 📄 페이지 375 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5625개)
#
# 📄 페이지 376 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5640개)
#
# 📄 페이지 377 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5655개)
#
# 📄 페이지 378 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5670개)
#
# 📄 페이지 379 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5685개)
#
# 📄 페이지 380 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5700개)
#
# 📄 페이지 381 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5715개)
#
# 📄 페이지 382 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5730개)
#
# 📄 페이지 383 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5745개)
#
# 📄 페이지 384 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5760개)
#
# 📄 페이지 385 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5775개)
#
# 📄 페이지 386 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5790개)
#
# 📄 페이지 387 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5805개)
#
# 📄 페이지 388 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5820개)
#
# 📄 페이지 389 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5835개)
#
# 📄 페이지 390 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5850개)
#
# 📄 페이지 391 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5865개)
#
# 📄 페이지 392 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5880개)
#
# 📄 페이지 393 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5895개)
#
# 📄 페이지 394 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5910개)
#
# 📄 페이지 395 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5925개)
#
# 📄 페이지 396 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5940개)
#
# 📄 페이지 397 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5955개)
#
# 📄 페이지 398 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5970개)
#
# 📄 페이지 399 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 5985개)
#
# 📄 페이지 400 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6000개)
#
# 📄 페이지 401 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6015개)
#
# 📄 페이지 402 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6030개)
#
# 📄 페이지 403 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6045개)
#
# 📄 페이지 404 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6060개)
#
# 📄 페이지 405 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6075개)
#
# 📄 페이지 406 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6090개)
#
# 📄 페이지 407 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6105개)
#
# 📄 페이지 408 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6120개)
#
# 📄 페이지 409 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6135개)
#
# 📄 페이지 410 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6150개)
#
# 📄 페이지 411 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6165개)
#
# 📄 페이지 412 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6180개)
#
# 📄 페이지 413 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6195개)
#
# 📄 페이지 414 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6210개)
#
# 📄 페이지 415 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6225개)
#
# 📄 페이지 416 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6240개)
#
# 📄 페이지 417 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6255개)
#
# 📄 페이지 418 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6270개)
#
# 📄 페이지 419 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6285개)
#
# 📄 페이지 420 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6300개)
#
# 📄 페이지 421 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6315개)
#
# 📄 페이지 422 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6330개)
#
# 📄 페이지 423 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6345개)
#
# 📄 페이지 424 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6360개)
#
# 📄 페이지 425 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6375개)
#
# 📄 페이지 426 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6390개)
#
# 📄 페이지 427 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6405개)
#
# 📄 페이지 428 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6420개)
#
# 📄 페이지 429 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6435개)
#
# 📄 페이지 430 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6450개)
#
# 📄 페이지 431 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6465개)
#
# 📄 페이지 432 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6480개)
#
# 📄 페이지 433 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6495개)
#
# 📄 페이지 434 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6510개)
#
# 📄 페이지 435 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6525개)
#
# 📄 페이지 436 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6540개)
#
# 📄 페이지 437 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6555개)
#
# 📄 페이지 438 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6570개)
#
# 📄 페이지 439 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6585개)
#
# 📄 페이지 440 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6600개)
#
# 📄 페이지 441 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6615개)
#
# 📄 페이지 442 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6630개)
#
# 📄 페이지 443 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6645개)
#
# 📄 페이지 444 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6660개)
#
# 📄 페이지 445 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6675개)
#
# 📄 페이지 446 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6690개)
#
# 📄 페이지 447 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6705개)
#
# 📄 페이지 448 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6720개)
#
# 📄 페이지 449 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6735개)
#
# 📄 페이지 450 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6750개)
#
# 📄 페이지 451 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6765개)
#
# 📄 페이지 452 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6780개)
#
# 📄 페이지 453 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6795개)
#
# 📄 페이지 454 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6810개)
#
# 📄 페이지 455 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6825개)
#
# 📄 페이지 456 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6840개)
#
# 📄 페이지 457 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6855개)
#
# 📄 페이지 458 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6870개)
#
# 📄 페이지 459 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6885개)
#
# 📄 페이지 460 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6900개)
#
# 📄 페이지 461 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6915개)
#
# 📄 페이지 462 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6930개)
#
# 📄 페이지 463 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6945개)
#
# 📄 페이지 464 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6960개)
#
# 📄 페이지 465 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6975개)
#
# 📄 페이지 466 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 6990개)
#
# 📄 페이지 467 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7005개)
#
# 📄 페이지 468 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7020개)
#
# 📄 페이지 469 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7035개)
#
# 📄 페이지 470 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7050개)
#
# 📄 페이지 471 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7065개)
#
# 📄 페이지 472 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7080개)
#
# 📄 페이지 473 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7095개)
#
# 📄 페이지 474 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7110개)
#
# 📄 페이지 475 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7125개)
#
# 📄 페이지 476 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7140개)
#
# 📄 페이지 477 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7155개)
#
# 📄 페이지 478 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7170개)
#
# 📄 페이지 479 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7185개)
#
# 📄 페이지 480 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7200개)
#
# 📄 페이지 481 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7215개)
#
# 📄 페이지 482 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7230개)
#
# 📄 페이지 483 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7245개)
#
# 📄 페이지 484 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7260개)
#
# 📄 페이지 485 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7275개)
#
# 📄 페이지 486 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7290개)
#
# 📄 페이지 487 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7305개)
#
# 📄 페이지 488 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7320개)
#
# 📄 페이지 489 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7335개)
#
# 📄 페이지 490 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7350개)
#
# 📄 페이지 491 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7365개)
#
# 📄 페이지 492 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7380개)
#
# 📄 페이지 493 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7395개)
#
# 📄 페이지 494 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7410개)
#
# 📄 페이지 495 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7425개)
#
# 📄 페이지 496 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7440개)
#
# 📄 페이지 497 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7455개)
#
# 📄 페이지 498 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7470개)
#
# 📄 페이지 499 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7485개)
#
# 📄 페이지 500 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7500개)
#
# 📄 페이지 501 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7515개)
#
# 📄 페이지 502 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7530개)
#
# 📄 페이지 503 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7545개)
#
# 📄 페이지 504 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7560개)
#
# 📄 페이지 505 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7575개)
#
# 📄 페이지 506 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7590개)
#
# 📄 페이지 507 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7605개)
#
# 📄 페이지 508 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7620개)
#
# 📄 페이지 509 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7635개)
#
# 📄 페이지 510 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7650개)
#
# 📄 페이지 511 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7665개)
#
# 📄 페이지 512 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7680개)
#
# 📄 페이지 513 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7695개)
#
# 📄 페이지 514 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7710개)
#
# 📄 페이지 515 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7725개)
#
# 📄 페이지 516 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7740개)
#
# 📄 페이지 517 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7755개)
#
# 📄 페이지 518 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7770개)
#
# 📄 페이지 519 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7785개)
#
# 📄 페이지 520 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7800개)
#
# 📄 페이지 521 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7815개)
#
# 📄 페이지 522 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7830개)
#
# 📄 페이지 523 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7845개)
#
# 📄 페이지 524 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7860개)
#
# 📄 페이지 525 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7875개)
#
# 📄 페이지 526 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7890개)
#
# 📄 페이지 527 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7905개)
#
# 📄 페이지 528 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7920개)
#
# 📄 페이지 529 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7935개)
#
# 📄 페이지 530 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7950개)
#
# 📄 페이지 531 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7965개)
#
# 📄 페이지 532 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7980개)
#
# 📄 페이지 533 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 7995개)
#
# 📄 페이지 534 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8010개)
#
# 📄 페이지 535 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8025개)
#
# 📄 페이지 536 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8040개)
#
# 📄 페이지 537 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8055개)
#
# 📄 페이지 538 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8070개)
#
# 📄 페이지 539 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8085개)
#
# 📄 페이지 540 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8100개)
#
# 📄 페이지 541 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8115개)
#
# 📄 페이지 542 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8130개)
#
# 📄 페이지 543 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8145개)
#
# 📄 페이지 544 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8160개)
#
# 📄 페이지 545 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8175개)
#
# 📄 페이지 546 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8190개)
#
# 📄 페이지 547 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8205개)
#
# 📄 페이지 548 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8220개)
#
# 📄 페이지 549 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8235개)
#
# 📄 페이지 550 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8250개)
#
# 📄 페이지 551 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8265개)
#
# 📄 페이지 552 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8280개)
#
# 📄 페이지 553 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8295개)
#
# 📄 페이지 554 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8310개)
#
# 📄 페이지 555 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8325개)
#
# 📄 페이지 556 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8340개)
#
# 📄 페이지 557 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8355개)
#
# 📄 페이지 558 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8370개)
#
# 📄 페이지 559 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8385개)
#
# 📄 페이지 560 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8400개)
#
# 📄 페이지 561 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8415개)
#
# 📄 페이지 562 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8430개)
#
# 📄 페이지 563 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8445개)
#
# 📄 페이지 564 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8460개)
#
# 📄 페이지 565 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8475개)
#
# 📄 페이지 566 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8490개)
#
# 📄 페이지 567 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8505개)
#
# 📄 페이지 568 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8520개)
#
# 📄 페이지 569 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8535개)
#
# 📄 페이지 570 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8550개)
#
# 📄 페이지 571 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8565개)
#
# 📄 페이지 572 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8580개)
#
# 📄 페이지 573 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8595개)
#
# 📄 페이지 574 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8610개)
#
# 📄 페이지 575 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8625개)
#
# 📄 페이지 576 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8640개)
#
# 📄 페이지 577 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8655개)
#
# 📄 페이지 578 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8670개)
#
# 📄 페이지 579 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8685개)
#
# 📄 페이지 580 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8700개)
#
# 📄 페이지 581 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8715개)
#
# 📄 페이지 582 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8730개)
#
# 📄 페이지 583 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8745개)
#
# 📄 페이지 584 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8760개)
#
# 📄 페이지 585 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8775개)
#
# 📄 페이지 586 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8790개)
#
# 📄 페이지 587 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8805개)
#
# 📄 페이지 588 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8820개)
#
# 📄 페이지 589 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8835개)
#
# 📄 페이지 590 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8850개)
#
# 📄 페이지 591 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8865개)
#
# 📄 페이지 592 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8880개)
#
# 📄 페이지 593 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8895개)
#
# 📄 페이지 594 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8910개)
#
# 📄 페이지 595 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8925개)
#
# 📄 페이지 596 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8940개)
#
# 📄 페이지 597 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8955개)
#
# 📄 페이지 598 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8970개)
#
# 📄 페이지 599 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 8985개)
#
# 📄 페이지 600 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9000개)
#
# 📄 페이지 601 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9015개)
#
# 📄 페이지 602 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9030개)
#
# 📄 페이지 603 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9045개)
#
# 📄 페이지 604 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9060개)
#
# 📄 페이지 605 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9075개)
#
# 📄 페이지 606 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9090개)
#
# 📄 페이지 607 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9105개)
#
# 📄 페이지 608 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9120개)
#
# 📄 페이지 609 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9135개)
#
# 📄 페이지 610 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9150개)
#
# 📄 페이지 611 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9165개)
#
# 📄 페이지 612 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9180개)
#
# 📄 페이지 613 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9195개)
#
# 📄 페이지 614 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9210개)
#
# 📄 페이지 615 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9225개)
#
# 📄 페이지 616 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9240개)
#
# 📄 페이지 617 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9255개)
#
# 📄 페이지 618 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9270개)
#
# 📄 페이지 619 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9285개)
#
# 📄 페이지 620 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9300개)
#
# 📄 페이지 621 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9315개)
#
# 📄 페이지 622 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9330개)
#
# 📄 페이지 623 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9345개)
#
# 📄 페이지 624 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9360개)
#
# 📄 페이지 625 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9375개)
#
# 📄 페이지 626 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9390개)
#
# 📄 페이지 627 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9405개)
#
# 📄 페이지 628 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9420개)
#
# 📄 페이지 629 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9435개)
#
# 📄 페이지 630 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9450개)
#
# 📄 페이지 631 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9465개)
#
# 📄 페이지 632 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9480개)
#
# 📄 페이지 633 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9495개)
#
# 📄 페이지 634 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9510개)
#
# 📄 페이지 635 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9525개)
#
# 📄 페이지 636 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9540개)
#
# 📄 페이지 637 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9555개)
#
# 📄 페이지 638 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9570개)
#
# 📄 페이지 639 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9585개)
#
# 📄 페이지 640 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9600개)
#
# 📄 페이지 641 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9615개)
#
# 📄 페이지 642 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9630개)
#
# 📄 페이지 643 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9645개)
#
# 📄 페이지 644 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9660개)
#
# 📄 페이지 645 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9675개)
#
# 📄 페이지 646 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9690개)
#
# 📄 페이지 647 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9705개)
#
# 📄 페이지 648 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9720개)
#
# 📄 페이지 649 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9735개)
#
# 📄 페이지 650 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9750개)
#
# 📄 페이지 651 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9765개)
#
# 📄 페이지 652 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9780개)
#
# 📄 페이지 653 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9795개)
#
# 📄 페이지 654 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9810개)
#
# 📄 페이지 655 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9825개)
#
# 📄 페이지 656 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9840개)
#
# 📄 페이지 657 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9855개)
#
# 📄 페이지 658 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9870개)
#
# 📄 페이지 659 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9885개)
#
# 📄 페이지 660 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9900개)
#
# 📄 페이지 661 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9915개)
#
# 📄 페이지 662 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9930개)
#
# 📄 페이지 663 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9945개)
#
# 📄 페이지 664 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9960개)
#
# 📄 페이지 665 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9975개)
#
# 📄 페이지 666 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 9990개)
#
# 📄 페이지 667 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10005개)
#
# 📄 페이지 668 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10020개)
#
# 📄 페이지 669 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10035개)
#
# 📄 페이지 670 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10050개)
#
# 📄 페이지 671 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10065개)
#
# 📄 페이지 672 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10080개)
#
# 📄 페이지 673 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10095개)
#
# 📄 페이지 674 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10110개)
#
# 📄 페이지 675 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10125개)
#
# 📄 페이지 676 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10140개)
#
# 📄 페이지 677 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10155개)
#
# 📄 페이지 678 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10170개)
#
# 📄 페이지 679 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10185개)
#
# 📄 페이지 680 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10200개)
#
# 📄 페이지 681 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10215개)
#
# 📄 페이지 682 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10230개)
#
# 📄 페이지 683 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10245개)
#
# 📄 페이지 684 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10260개)
#
# 📄 페이지 685 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10275개)
#
# 📄 페이지 686 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10290개)
#
# 📄 페이지 687 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10305개)
#
# 📄 페이지 688 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10320개)
#
# 📄 페이지 689 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10335개)
#
# 📄 페이지 690 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10350개)
#
# 📄 페이지 691 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10365개)
#
# 📄 페이지 692 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10380개)
#
# 📄 페이지 693 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10395개)
#
# 📄 페이지 694 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10410개)
#
# 📄 페이지 695 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10425개)
#
# 📄 페이지 696 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10440개)
#
# 📄 페이지 697 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10455개)
#
# 📄 페이지 698 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10470개)
#
# 📄 페이지 699 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10485개)
#
# 📄 페이지 700 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10500개)
#
# 📄 페이지 701 URL 수집 중...
#   ✓ 15개 URL 수집 (누적: 10515개)
#
# 📄 페이지 702 URL 수집 중...
# ⚠️ 페이지 702 처리 중 오류: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://terms.naver.com/medicineSearch.naver?mode=exteriorSearch&shape=&color=&dosageForm=&divisionLine=&identifier=&page=702", waiting until "networkidle"
#
#
# ✅ 총 10515개의 URL 수집 완료!
#
# ✅ URL 목록 저장: all_medicine_urls.json
#
# ============================================================
# 🔍 2단계: 전문의약품 크롤링 시작...
# ============================================================
#
# [1/10515] 🔍 처리 중...
#
# [2/10515] 🔍 처리 중...
#
# [3/10515] 🔍 처리 중...
#
# [4/10515] 🔍 처리 중...
#
# [5/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 1/200, 총: 1개)
#
# [6/10515] 🔍 처리 중...
#
# [7/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 2/200, 총: 2개)
#
# [8/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 3/200, 총: 3개)
#
# [9/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 4/200, 총: 4개)
#
# [10/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 5/200, 총: 5개)
#
# [11/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 6/200, 총: 6개)
#
# [12/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 7/200, 총: 7개)
#
# [13/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 8/200, 총: 8개)
#
# [14/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 9/200, 총: 9개)
#
# [15/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 10/200, 총: 10개)
#
# [16/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 11/200, 총: 11개)
#
# [17/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 12/200, 총: 12개)
#
# [18/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 13/200, 총: 13개)
#
# [19/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 14/200, 총: 14개)
#
# [20/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 15/200, 총: 15개)
#
# [21/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 16/200, 총: 16개)
#
# [22/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 17/200, 총: 17개)
#
# [23/10515] 🔍 처리 중...
#
# [24/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 18/200, 총: 18개)
#
# [25/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 19/200, 총: 19개)
#
# [26/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 20/200, 총: 20개)
#
# [27/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 21/200, 총: 21개)
#
# [28/10515] 🔍 처리 중...
#
# [29/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 22/200, 총: 22개)
#
# [30/10515] 🔍 처리 중...
#   ⏭️  스킵 (총 스킵: 8개)
#
# [31/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 23/200, 총: 23개)
#
# [32/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 24/200, 총: 24개)
#
# [33/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 25/200, 총: 25개)
#
# [34/10515] 🔍 처리 중...
#
# [35/10515] 🔍 처리 중...
#
# [36/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 26/200, 총: 26개)
#
# [37/10515] 🔍 처리 중...
#
# [38/10515] 🔍 처리 중...
#
# [39/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 27/200, 총: 27개)
#
# [40/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 28/200, 총: 28개)
#
# [41/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 29/200, 총: 29개)
#
# [42/10515] 🔍 처리 중...
#
# [43/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 30/200, 총: 30개)
#
# [44/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 31/200, 총: 31개)
#
# [45/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 32/200, 총: 32개)
#
# [46/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 33/200, 총: 33개)
#
# [47/10515] 🔍 처리 중...
#
# [48/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 34/200, 총: 34개)
#
# [49/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 35/200, 총: 35개)
#
# [50/10515] 🔍 처리 중...
#   ⏭️  스킵 (총 스킵: 15개)
#
# [51/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 36/200, 총: 36개)
#
# [52/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 37/200, 총: 37개)
#
# [53/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 38/200, 총: 38개)
#
# [54/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 39/200, 총: 39개)
#
# [55/10515] 🔍 처리 중...
#
# [56/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 40/200, 총: 40개)
#
# [57/10515] 🔍 처리 중...
#
# [58/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 41/200, 총: 41개)
#
# [59/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 42/200, 총: 42개)
#
# [60/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 43/200, 총: 43개)
#
# [61/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 44/200, 총: 44개)
#
# [62/10515] 🔍 처리 중...
#
# [63/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 45/200, 총: 45개)
#
# [64/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 46/200, 총: 46개)
#
# [65/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 47/200, 총: 47개)
#
# [66/10515] 🔍 처리 중...
#
# [67/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 48/200, 총: 48개)
#
# [68/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 49/200, 총: 49개)
#
# [69/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 50/200, 총: 50개)
#
# [70/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 51/200, 총: 51개)
#
# [71/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 52/200, 총: 52개)
#
# [72/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 53/200, 총: 53개)
#
# [73/10515] 🔍 처리 중...
#
# [74/10515] 🔍 처리 중...
#
# [75/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 54/200, 총: 54개)
#
# [76/10515] 🔍 처리 중...
#
# [77/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 55/200, 총: 55개)
#
# [78/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 56/200, 총: 56개)
#
# [79/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 57/200, 총: 57개)
#
# [80/10515] 🔍 처리 중...
#   ⏭️  스킵 (총 스킵: 23개)
#
# [81/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 58/200, 총: 58개)
#
# [82/10515] 🔍 처리 중...
#
# [83/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 59/200, 총: 59개)
#
# [84/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 60/200, 총: 60개)
#
# [85/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 61/200, 총: 61개)
#
# [86/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 62/200, 총: 62개)
#
# [87/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 63/200, 총: 63개)
#
# [88/10515] 🔍 처리 중...
#
# [89/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 64/200, 총: 64개)
#
# [90/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 65/200, 총: 65개)
#
# [91/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 66/200, 총: 66개)
#
# [92/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 67/200, 총: 67개)
#
# [93/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 68/200, 총: 68개)
#
# [94/10515] 🔍 처리 중...
#
# [95/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 69/200, 총: 69개)
#
# [96/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 70/200, 총: 70개)
#
# [97/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 71/200, 총: 71개)
#
# [98/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 72/200, 총: 72개)
#
# [99/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 73/200, 총: 73개)
#
# [100/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 74/200, 총: 74개)
#
# [101/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 75/200, 총: 75개)
#
# [102/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 76/200, 총: 76개)
#
# [103/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 77/200, 총: 77개)
#
# [104/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 78/200, 총: 78개)
#
# [105/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 79/200, 총: 79개)
#
# [106/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 80/200, 총: 80개)
#
# [107/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 81/200, 총: 81개)
#
# [108/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 82/200, 총: 82개)
#
# [109/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 83/200, 총: 83개)
#
# [110/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 84/200, 총: 84개)
#
# [111/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 85/200, 총: 85개)
#
# [112/10515] 🔍 처리 중...
#
# [113/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 86/200, 총: 86개)
#
# [114/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 87/200, 총: 87개)
#
# [115/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 88/200, 총: 88개)
#
# [116/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 89/200, 총: 89개)
#
# [117/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 90/200, 총: 90개)
#
# [118/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 91/200, 총: 91개)
#
# [119/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 92/200, 총: 92개)
#
# [120/10515] 🔍 처리 중...
#   ⏭️  스킵 (총 스킵: 28개)
#
# [121/10515] 🔍 처리 중...
#
# [122/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 93/200, 총: 93개)
#
# [123/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 94/200, 총: 94개)
#
# [124/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 95/200, 총: 95개)
#
# [125/10515] 🔍 처리 중...
#
# [126/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 96/200, 총: 96개)
#
# [127/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 97/200, 총: 97개)
#
# [128/10515] 🔍 처리 중...
#
# [129/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 98/200, 총: 98개)
#
# [130/10515] 🔍 처리 중...
#   ⏭️  스킵 (총 스킵: 32개)
#
# [131/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 99/200, 총: 99개)
#
# [132/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 100/200, 총: 100개)
#
# [133/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 101/200, 총: 101개)
#
# [134/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 102/200, 총: 102개)
#
# [135/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 103/200, 총: 103개)
#
# [136/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 104/200, 총: 104개)
#
# [137/10515] 🔍 처리 중...
#
# [138/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 105/200, 총: 105개)
#
# [139/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 106/200, 총: 106개)
#
# [140/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 107/200, 총: 107개)
#
# [141/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 108/200, 총: 108개)
#
# [142/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 109/200, 총: 109개)
#
# [143/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 110/200, 총: 110개)
#
# [144/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 111/200, 총: 111개)
#
# [145/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 112/200, 총: 112개)
#
# [146/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 113/200, 총: 113개)
#
# [147/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 114/200, 총: 114개)
#
# [148/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 115/200, 총: 115개)
#
# [149/10515] 🔍 처리 중...
#
# [150/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 116/200, 총: 116개)
#
# [151/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 117/200, 총: 117개)
#
# [152/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 118/200, 총: 118개)
#
# [153/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 119/200, 총: 119개)
#
# [154/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 120/200, 총: 120개)
#
# [155/10515] 🔍 처리 중...
#
# [156/10515] 🔍 처리 중...
#
# [157/10515] 🔍 처리 중...
#
# [158/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 121/200, 총: 121개)
#
# [159/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 122/200, 총: 122개)
#
# [160/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 123/200, 총: 123개)
#
# [161/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 124/200, 총: 124개)
#
# [162/10515] 🔍 처리 중...
#
# [163/10515] 🔍 처리 중...
#
# [164/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 125/200, 총: 125개)
#
# [165/10515] 🔍 처리 중...
#
# [166/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 126/200, 총: 126개)
#
# [167/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 127/200, 총: 127개)
#
# [168/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 128/200, 총: 128개)
#
# [169/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 129/200, 총: 129개)
#
# [170/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 130/200, 총: 130개)
#
# [171/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 131/200, 총: 131개)
#
# [172/10515] 🔍 처리 중...
#
# [173/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 132/200, 총: 132개)
#
# [174/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 133/200, 총: 133개)
#
# [175/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 134/200, 총: 134개)
#
# [176/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 135/200, 총: 135개)
#
# [177/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 136/200, 총: 136개)
#
# [178/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 137/200, 총: 137개)
#
# [179/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 138/200, 총: 138개)
#
# [180/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 139/200, 총: 139개)
#
# [181/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 140/200, 총: 140개)
#
# [182/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 141/200, 총: 141개)
#
# [183/10515] 🔍 처리 중...
#
# [184/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 142/200, 총: 142개)
#
# [185/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 143/200, 총: 143개)
#
# [186/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 144/200, 총: 144개)
#
# [187/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 145/200, 총: 145개)
#
# [188/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 146/200, 총: 146개)
#
# [189/10515] 🔍 처리 중...
#
# [190/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 147/200, 총: 147개)
#
# [191/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 148/200, 총: 148개)
#
# [192/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 149/200, 총: 149개)
#
# [193/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 150/200, 총: 150개)
#
# [194/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 151/200, 총: 151개)
#
# [195/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 152/200, 총: 152개)
#
# [196/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 153/200, 총: 153개)
#
# [197/10515] 🔍 처리 중...
#
# [198/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 154/200, 총: 154개)
#
# [199/10515] 🔍 처리 중...
#
# [200/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 155/200, 총: 155개)
#
# [201/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 156/200, 총: 156개)
#
# [202/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 157/200, 총: 157개)
#
# [203/10515] 🔍 처리 중...
#
# [204/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 158/200, 총: 158개)
#
# [205/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 159/200, 총: 159개)
#
# [206/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 160/200, 총: 160개)
#
# [207/10515] 🔍 처리 중...
#
# [208/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 161/200, 총: 161개)
#
# [209/10515] 🔍 처리 중...
#
# [210/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 162/200, 총: 162개)
#
# [211/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 163/200, 총: 163개)
#
# [212/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 164/200, 총: 164개)
#
# [213/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 165/200, 총: 165개)
#
# [214/10515] 🔍 처리 중...
#
# [215/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 166/200, 총: 166개)
#
# [216/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 167/200, 총: 167개)
#
# [217/10515] 🔍 처리 중...
#
# [218/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 168/200, 총: 168개)
#
# [219/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 169/200, 총: 169개)
#
# [220/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 170/200, 총: 170개)
#
# [221/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 171/200, 총: 171개)
#
# [222/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 172/200, 총: 172개)
#
# [223/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 173/200, 총: 173개)
#
# [224/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 174/200, 총: 174개)
#
# [225/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 175/200, 총: 175개)
#
# [226/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 176/200, 총: 176개)
#
# [227/10515] 🔍 처리 중...
#
# [228/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 177/200, 총: 177개)
#
# [229/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 178/200, 총: 178개)
#
# [230/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 179/200, 총: 179개)
#
# [231/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 180/200, 총: 180개)
#
# [232/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 181/200, 총: 181개)
#
# [233/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 182/200, 총: 182개)
#
# [234/10515] 🔍 처리 중...
# ...
#   ✅ 전문의약품 수집 완료 (배치: 197/200, 총: 7997개)
#
# [10236/10515] 🔍 처리 중...
#
# [10237/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 198/200, 총: 7998개)
#
# [10238/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 199/200, 총: 7999개)
#
# [10239/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 200/200, 총: 8000개)
#
# 💾 배치 저장: data/200개_40.csv (200건)
#
# [10240/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 1/200, 총: 8001개)
#
# [10241/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 2/200, 총: 8002개)
#
# [10242/10515] 🔍 처리 중...
#
# [10243/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 3/200, 총: 8003개)
#
# [10244/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 4/200, 총: 8004개)
#
# [10245/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 5/200, 총: 8005개)
#
# [10246/10515] 🔍 처리 중...
#
# [10247/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 6/200, 총: 8006개)
#
# [10248/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 7/200, 총: 8007개)
#
# [10249/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 8/200, 총: 8008개)
#
# [10250/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 9/200, 총: 8009개)
#
# [10251/10515] 🔍 처리 중...
#
# [10252/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 10/200, 총: 8010개)
#
# [10253/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 11/200, 총: 8011개)
#
# [10254/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 12/200, 총: 8012개)
#
# [10255/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 13/200, 총: 8013개)
#
# [10256/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 14/200, 총: 8014개)
#
# [10257/10515] 🔍 처리 중...
#
# [10258/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 15/200, 총: 8015개)
#
# [10259/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 16/200, 총: 8016개)
#
# [10260/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 17/200, 총: 8017개)
#
# [10261/10515] 🔍 처리 중...
#
# [10262/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 18/200, 총: 8018개)
#
# [10263/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 19/200, 총: 8019개)
#
# [10264/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 20/200, 총: 8020개)
#
# [10265/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 21/200, 총: 8021개)
#
# [10266/10515] 🔍 처리 중...
#
# [10267/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 22/200, 총: 8022개)
#
# [10268/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 23/200, 총: 8023개)
#
# [10269/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 24/200, 총: 8024개)
#
# [10270/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 25/200, 총: 8025개)
#
# [10271/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 26/200, 총: 8026개)
#
# [10272/10515] 🔍 처리 중...
#
# [10273/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 27/200, 총: 8027개)
#
# [10274/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 28/200, 총: 8028개)
#
# [10275/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 29/200, 총: 8029개)
#
# [10276/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 30/200, 총: 8030개)
#
# [10277/10515] 🔍 처리 중...
#
# [10278/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 31/200, 총: 8031개)
#
# [10279/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 32/200, 총: 8032개)
#
# [10280/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 33/200, 총: 8033개)
#
# [10281/10515] 🔍 처리 중...
#
# [10282/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 34/200, 총: 8034개)
#
# [10283/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 35/200, 총: 8035개)
#
# [10284/10515] 🔍 처리 중...
#
# [10285/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 36/200, 총: 8036개)
#
# [10286/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 37/200, 총: 8037개)
#
# [10287/10515] 🔍 처리 중...
#
# [10288/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 38/200, 총: 8038개)
#
# [10289/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 39/200, 총: 8039개)
#
# [10290/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 40/200, 총: 8040개)
#
# [10291/10515] 🔍 처리 중...
#
# [10292/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 41/200, 총: 8041개)
#
# [10293/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 42/200, 총: 8042개)
#
# [10294/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 43/200, 총: 8043개)
#
# [10295/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 44/200, 총: 8044개)
#
# [10296/10515] 🔍 처리 중...
#
# [10297/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 45/200, 총: 8045개)
#
# [10298/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 46/200, 총: 8046개)
#
# [10299/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 47/200, 총: 8047개)
#
# [10300/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 48/200, 총: 8048개)
#
# [10301/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 49/200, 총: 8049개)
#
# [10302/10515] 🔍 처리 중...
#
# [10303/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 50/200, 총: 8050개)
#
# [10304/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 51/200, 총: 8051개)
#
# [10305/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 52/200, 총: 8052개)
#
# [10306/10515] 🔍 처리 중...
#
# [10307/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 53/200, 총: 8053개)
#
# [10308/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 54/200, 총: 8054개)
#
# [10309/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 55/200, 총: 8055개)
#
# [10310/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 56/200, 총: 8056개)
#
# [10311/10515] 🔍 처리 중...
#
# [10312/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 57/200, 총: 8057개)
#
# [10313/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 58/200, 총: 8058개)
#
# [10314/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 59/200, 총: 8059개)
#
# [10315/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 60/200, 총: 8060개)
#
# [10316/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 61/200, 총: 8061개)
#
# [10317/10515] 🔍 처리 중...
#
# [10318/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 62/200, 총: 8062개)
#
# [10319/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 63/200, 총: 8063개)
#
# [10320/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 64/200, 총: 8064개)
#
# [10321/10515] 🔍 처리 중...
#
# [10322/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 65/200, 총: 8065개)
#
# [10323/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 66/200, 총: 8066개)
#
# [10324/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 67/200, 총: 8067개)
#
# [10325/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 68/200, 총: 8068개)
#
# [10326/10515] 🔍 처리 중...
#
# [10327/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 69/200, 총: 8069개)
#
# [10328/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 70/200, 총: 8070개)
#
# [10329/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 71/200, 총: 8071개)
#
# [10330/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 72/200, 총: 8072개)
#
# [10331/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 73/200, 총: 8073개)
#
# [10332/10515] 🔍 처리 중...
#
# [10333/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 74/200, 총: 8074개)
#
# [10334/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 75/200, 총: 8075개)
#
# [10335/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 76/200, 총: 8076개)
#
# [10336/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 77/200, 총: 8077개)
#
# [10337/10515] 🔍 처리 중...
#
# [10338/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 78/200, 총: 8078개)
#
# [10339/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 79/200, 총: 8079개)
#
# [10340/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 80/200, 총: 8080개)
#
# [10341/10515] 🔍 처리 중...
#
# [10342/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 81/200, 총: 8081개)
#
# [10343/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 82/200, 총: 8082개)
#
# [10344/10515] 🔍 처리 중...
#
# [10345/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 83/200, 총: 8083개)
#
# [10346/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 84/200, 총: 8084개)
#
# [10347/10515] 🔍 처리 중...
#
# [10348/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 85/200, 총: 8085개)
#
# [10349/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 86/200, 총: 8086개)
#
# [10350/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 87/200, 총: 8087개)
#
# [10351/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 88/200, 총: 8088개)
#
# [10352/10515] 🔍 처리 중...
#
# [10353/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 89/200, 총: 8089개)
#
# [10354/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 90/200, 총: 8090개)
#
# [10355/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 91/200, 총: 8091개)
#
# [10356/10515] 🔍 처리 중...
#
# [10357/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 92/200, 총: 8092개)
#
# [10358/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 93/200, 총: 8093개)
#
# [10359/10515] 🔍 처리 중...
#
# [10360/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 94/200, 총: 8094개)
#
# [10361/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 95/200, 총: 8095개)
#
# [10362/10515] 🔍 처리 중...
#
# [10363/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 96/200, 총: 8096개)
#
# [10364/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 97/200, 총: 8097개)
#
# [10365/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 98/200, 총: 8098개)
#
# [10366/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 99/200, 총: 8099개)
#
# [10367/10515] 🔍 처리 중...
#
# [10368/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 100/200, 총: 8100개)
#
# [10369/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 101/200, 총: 8101개)
#
# [10370/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 102/200, 총: 8102개)
#
# [10371/10515] 🔍 처리 중...
#
# [10372/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 103/200, 총: 8103개)
#
# [10373/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 104/200, 총: 8104개)
#
# [10374/10515] 🔍 처리 중...
#
# [10375/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 105/200, 총: 8105개)
#
# [10376/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 106/200, 총: 8106개)
#
# [10377/10515] 🔍 처리 중...
#
# [10378/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 107/200, 총: 8107개)
#
# [10379/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 108/200, 총: 8108개)
#
# [10380/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 109/200, 총: 8109개)
#
# [10381/10515] 🔍 처리 중...
#
# [10382/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 110/200, 총: 8110개)
#
# [10383/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 111/200, 총: 8111개)
#
# [10384/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 112/200, 총: 8112개)
#
# [10385/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 113/200, 총: 8113개)
#
# [10386/10515] 🔍 처리 중...
#
# [10387/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 114/200, 총: 8114개)
#
# [10388/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 115/200, 총: 8115개)
#
# [10389/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 116/200, 총: 8116개)
#
# [10390/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 117/200, 총: 8117개)
#
# [10391/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 118/200, 총: 8118개)
#
# [10392/10515] 🔍 처리 중...
#
# [10393/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 119/200, 총: 8119개)
#
# [10394/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 120/200, 총: 8120개)
#
# [10395/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 121/200, 총: 8121개)
#
# [10396/10515] 🔍 처리 중...
#
# [10397/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 122/200, 총: 8122개)
#
# [10398/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 123/200, 총: 8123개)
#
# [10399/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 124/200, 총: 8124개)
#
# [10400/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 125/200, 총: 8125개)
#
# [10401/10515] 🔍 처리 중...
#
# [10402/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 126/200, 총: 8126개)
#
# [10403/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 127/200, 총: 8127개)
#
# [10404/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 128/200, 총: 8128개)
#
# [10405/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 129/200, 총: 8129개)
#
# [10406/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 130/200, 총: 8130개)
#
# [10407/10515] 🔍 처리 중...
#
# [10408/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 131/200, 총: 8131개)
#
# [10409/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 132/200, 총: 8132개)
#
# [10410/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 133/200, 총: 8133개)
#
# [10411/10515] 🔍 처리 중...
#
# [10412/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 134/200, 총: 8134개)
#
# [10413/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 135/200, 총: 8135개)
#
# [10414/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 136/200, 총: 8136개)
#
# [10415/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 137/200, 총: 8137개)
#
# [10416/10515] 🔍 처리 중...
#
# [10417/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 138/200, 총: 8138개)
#
# [10418/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 139/200, 총: 8139개)
#
# [10419/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 140/200, 총: 8140개)
#
# [10420/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 141/200, 총: 8141개)
#
# [10421/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 142/200, 총: 8142개)
#
# [10422/10515] 🔍 처리 중...
#
# [10423/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 143/200, 총: 8143개)
#
# [10424/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 144/200, 총: 8144개)
#
# [10425/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 145/200, 총: 8145개)
#
# [10426/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 146/200, 총: 8146개)
#
# [10427/10515] 🔍 처리 중...
#
# [10428/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 147/200, 총: 8147개)
#
# [10429/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 148/200, 총: 8148개)
#
# [10430/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 149/200, 총: 8149개)
#
# [10431/10515] 🔍 처리 중...
#
# [10432/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 150/200, 총: 8150개)
#
# [10433/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 151/200, 총: 8151개)
#
# [10434/10515] 🔍 처리 중...
#
# [10435/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 152/200, 총: 8152개)
#
# [10436/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 153/200, 총: 8153개)
#
# [10437/10515] 🔍 처리 중...
#
# [10438/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 154/200, 총: 8154개)
#
# [10439/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 155/200, 총: 8155개)
#
# [10440/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 156/200, 총: 8156개)
#
# [10441/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 157/200, 총: 8157개)
#
# [10442/10515] 🔍 처리 중...
#
# [10443/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 158/200, 총: 8158개)
#
# [10444/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 159/200, 총: 8159개)
#
# [10445/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 160/200, 총: 8160개)
#
# [10446/10515] 🔍 처리 중...
#
# [10447/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 161/200, 총: 8161개)
#
# [10448/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 162/200, 총: 8162개)
#
# [10449/10515] 🔍 처리 중...
#
# [10450/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 163/200, 총: 8163개)
#
# [10451/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 164/200, 총: 8164개)
#
# [10452/10515] 🔍 처리 중...
#
# [10453/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 165/200, 총: 8165개)
#
# [10454/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 166/200, 총: 8166개)
#
# [10455/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 167/200, 총: 8167개)
#
# [10456/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 168/200, 총: 8168개)
#
# [10457/10515] 🔍 처리 중...
#
# [10458/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 169/200, 총: 8169개)
#
# [10459/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 170/200, 총: 8170개)
#
# [10460/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 171/200, 총: 8171개)
#
# [10461/10515] 🔍 처리 중...
#
# [10462/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 172/200, 총: 8172개)
#
# [10463/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 173/200, 총: 8173개)
#
# [10464/10515] 🔍 처리 중...
#
# [10465/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 174/200, 총: 8174개)
#
# [10466/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 175/200, 총: 8175개)
#
# [10467/10515] 🔍 처리 중...
#
# [10468/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 176/200, 총: 8176개)
#
# [10469/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 177/200, 총: 8177개)
#
# [10470/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 178/200, 총: 8178개)
#
# [10471/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 179/200, 총: 8179개)
#
# [10472/10515] 🔍 처리 중...
#
# [10473/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 180/200, 총: 8180개)
#
# [10474/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 181/200, 총: 8181개)
#
# [10475/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 182/200, 총: 8182개)
#
# [10476/10515] 🔍 처리 중...
#
# [10477/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 183/200, 총: 8183개)
#
# [10478/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 184/200, 총: 8184개)
#
# [10479/10515] 🔍 처리 중...
#
# [10480/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 185/200, 총: 8185개)
#
# [10481/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 186/200, 총: 8186개)
#
# [10482/10515] 🔍 처리 중...
#
# [10483/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 187/200, 총: 8187개)
#
# [10484/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 188/200, 총: 8188개)
#
# [10485/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 189/200, 총: 8189개)
#
# [10486/10515] 🔍 처리 중...
#
# [10487/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 190/200, 총: 8190개)
#
# [10488/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 191/200, 총: 8191개)
#
# [10489/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 192/200, 총: 8192개)
#
# [10490/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 193/200, 총: 8193개)
#
# [10491/10515] 🔍 처리 중...
#
# [10492/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 194/200, 총: 8194개)
#
# [10493/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 195/200, 총: 8195개)
#
# [10494/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 196/200, 총: 8196개)
#
# [10495/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 197/200, 총: 8197개)
#
# [10496/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 198/200, 총: 8198개)
#
# [10497/10515] 🔍 처리 중...
#
# [10498/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 199/200, 총: 8199개)
#
# [10499/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 200/200, 총: 8200개)
#
# 💾 배치 저장: data/200개_41.csv (200건)
#
# [10500/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 1/200, 총: 8201개)
#
# [10501/10515] 🔍 처리 중...
#
# [10502/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 2/200, 총: 8202개)
#
# [10503/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 3/200, 총: 8203개)
#
# [10504/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 4/200, 총: 8204개)
#
# [10505/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 5/200, 총: 8205개)
#
# [10506/10515] 🔍 처리 중...
#
# [10507/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 6/200, 총: 8206개)
#
# [10508/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 7/200, 총: 8207개)
#
# [10509/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 8/200, 총: 8208개)
#
# [10510/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 9/200, 총: 8209개)
#
# [10511/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 10/200, 총: 8210개)
#
# [10512/10515] 🔍 처리 중...
#
# [10513/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 11/200, 총: 8211개)
#
# [10514/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 12/200, 총: 8212개)
#
# [10515/10515] 🔍 처리 중...
#   ✅ 전문의약품 수집 완료 (배치: 13/200, 총: 8213개)
#
# 💾 배치 저장: data/13개_42.csv (13건)
#
# ============================================================
# ✅ 크롤링 완료!
# ============================================================
#
# 전체 약품 수: 10515건
# 전문의약품: 8213건
# 일반의약품 등 (스킵): 2302건
# 크롤링 실패: 0건
# 저장된 배치 파일: 42개
# ============================================================
# ✅ 진행 상황 파일 삭제 완료
#
# ⏱️  총 소요 시간: 24.30시간 (1458.04분)
# ✅ 총 8213개의 전문의약품 수집 완료!

# %% [markdown]
# # 총 41개의 200개 csv + 1개의 13개 csv 저장 완료 !
# - 이제 이 csv들을 하나의 csv로 합치겠습니다

# %%
import pandas as pd
import glob

# 1) 패턴에 맞는 모든 CSV 파일 불러오기
file_list = glob.glob("data/200개_*.csv")

# 2) 읽은 파일을 리스트에 저장
dfs = [pd.read_csv(file) for file in file_list]

# 3) 하나로 합치기
df_all = pd.concat(dfs, ignore_index=True)

# %%
df_all.head()
# Out:
#                                                  url   doc_id  \
# 0  https://terms.naver.com/entry.naver?docId=5661...  5661792
# 1  https://terms.naver.com/entry.naver?docId=4355...  4355082
# 2  https://terms.naver.com/entry.naver?docId=5769...  5769641
# 3  https://terms.naver.com/entry.naver?docId=3613...  3613086
# 4  https://terms.naver.com/entry.naver?docId=6691...  6691324
#
#                                  약품명  \
# 0                   베스티온정(베포타스틴베실산염)
# 1                 모베타스프레이(모메타손푸로에이트)
# 2                     프리피펜주(아세트아미노펜)
# 3                     이뮤알파주(싸이모신알파1)
# 4  아토바미브정10/5mg(에제티미브, 아토르바스타틴칼슘삼...
#
#                                              이미지_URL                분류     구분  \
# 0  https://dbscthumb-phinf.pstatic.net/3323_000_3...     [01410]항히스타민제  전문의약품
# 1                                                NaN      [01320]이비과용제  전문의약품
# 2                                                NaN  [01140]해열.진통.소염제  전문의약품
# 3                                                NaN  [04290]기타의 종양치료제  전문의약품
# 4  https://dbscthumb-phinf.pstatic.net/3323_000_3...     [02180]동맥경화용제  전문의약품
#
#           업체명       보험코드              성상     제형  ...  \
# 0  에이치엘비제약(주)  647303390   흰색의 원형 필름코팅정제  필름코팅정  ...
# 1    (주)마더스제약  622803061             NaN    NaN  ...
# 2  제이더블유신약(주)        NaN             NaN    NaN  ...
# 3   (주)한국비엠아이        NaN             NaN    NaN  ...
# 4     (주)유한양행  642106070  분홍색의 장방형 필름코팅정  필름코팅정  ...
#
#                            크기     식별표기  분할선  \
# 0   (장축)7.1, (단축)7.1, (두께)3.0  EY, 분할선    -
# 1                         NaN      NaN  NaN
# 2                         NaN      NaN  NaN
# 3                         NaN      NaN  NaN
# 4  (장축)11.6, (단축)5.6, (두께)4.6  EA5, YH  NaN
#
#                                                 성분정보  \
# 0                    1정(125.4mg) 중\n베포타스틴베실산염 10.0mg
# 1                             1mL 중\n모메타손푸로에이트 0.5mg
# 2                            100ml\n아세트아미노펜 1000.0mg
# 3                              1바이알 중\n싸이모신알파1 1.6mg
# 4  1정312mg-에제티미브층\n에제티미브 10mg\n\n1정312mg-아토르바스타틴층...
#
#                                                 효능효과  \
# 0  다년성 알레르기성 비염, 만성 두드러기, 피부질환에 수반된 소양증(습진.피부염, 피...
# 1  1. 성인 및 2세 이상의 소아\n: 계절 알레르기비염 및 연중비염. 중등도 ～ 중...
# 2  통증이나 고열로 인하여 신속하게 정맥 투여할 필요가 있거나 다른 경로로 투여할 수 ...
# 3                 면역기능이 저하된 고령 환자의 인플루엔자 백신접종시의 보조요법
# 4  원발성 고콜레스테롤혈증\n원발성 고콜레스테롤혈증(이형접합 가족형 및 비가족형) 또는...
#
#                                                 용법용량               저장방법  \
# 0  통상, 성인에게는 베포타스틴베실산염으로서 1회 10mg을 1일 2회 경구투여한다. ...  기밀용기, 실온(1~30℃)보관
# 1  1. 알레르기 비염\n분무기를 1회 누를 때마다 모메타손푸로에이트 현탁액 약 100...  기밀용기, 실온보관(2～25℃)
# 2  정맥으로 투여하며, 성인, 체중 33kg(약 11세) 이상인 소아에 한함\n\n체중...  밀봉용기, 실온(1-30℃)보관
# 3  이 약 900ug/㎡(1바이알)을 백신접종 첫 주부터 4주간 주 2회씩 피하 또는 ...   밀봉용기, 2~8℃, 차광보관
# 4  이 약은 식사와 관계없이 1일 1회 투여한다.\n이 약을 투여하기 전 또는 투여 중...  기밀용기, 실온(1~30℃)보관
#
#            사용기간                                           사용상의주의사항  \
# 0  제조일로부터 36 개월  1. 다음 환자에게는 투여하지 말것\n이 약 성분에 과민증이 있는 환자\n\n2. ...
# 1  제조일로부터 24 개월  1. 다음 환자에는 투여하지 말 것.\n1) 이 약 또는 이 약의 구성성분에 대해 ...
# 2  제조일로부터 24 개월  1. 경고\n1) 투약 오류의 위험: 밀리그램과 밀리리터의 혼동으로 인한 투약 오류...
# 3  제조일로부터 36 개월  1. 다음 환자에는 투여하지 말 것\n1) 이 약 및 이 약의 성분에 과민증의 병력...
# 4  제조일로부터 24 개월  1. 경고\n아토르바스타틴 및 동일 계열의 다른 약물에서 미오글로빈뇨에 의한 이차적...
#
#                                   제품명
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4  아토바미브정10/5mg(에제티미브, 아토르바스타틴칼슘삼수화물)
#
# [5 rows x 22 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8200 entries, 0 to 8199
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   url       8200 non-null   object
#  1   doc_id    8200 non-null   int64
#  2   약품명       8200 non-null   object
#  3   이미지_URL   4683 non-null   object
#  4   분류        8198 non-null   object
#  5   구분        8200 non-null   object
#  6   업체명       8200 non-null   object
#  7   보험코드      6129 non-null   object
#  8   성상        4683 non-null   object
#  9   제형        4683 non-null   object
#  10  모양        4683 non-null   object
#  11  색깔        4683 non-null   object
#  12  크기        4683 non-null   object
#  13  식별표기      4676 non-null   object
#  14  분할선       1504 non-null   object
#  15  성분정보      8200 non-null   object
#  16  효능효과      8199 non-null   object
#  17  용법용량      8200 non-null   object
#  18  저장방법      8200 non-null   object
#  19  사용기간      8200 non-null   object
#  20  사용상의주의사항  8198 non-null   object
#  21  제품명       1252 non-null   object
# dtypes: int64(1), object(21)
# memory usage: 1.4+ MB

# %%
df_13 = pd.read_csv("data/13개_42.csv")

# %%
df_13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   url       13 non-null     object
#  1   doc_id    13 non-null     int64
#  2   약품명       13 non-null     object
#  3   이미지_URL   7 non-null      object
#  4   분류        13 non-null     object
#  5   구분        13 non-null     object
#  6   업체명       13 non-null     object
#  7   보험코드      10 non-null     float64
#  8   성상        7 non-null      object
#  9   제형        7 non-null      object
#  10  모양        7 non-null      object
#  11  색깔        7 non-null      object
#  12  크기        7 non-null      object
#  13  식별표기      7 non-null      object
#  14  성분정보      13 non-null     object
#  15  효능효과      13 non-null     object
#  16  용법용량      13 non-null     object
#  17  저장방법      13 non-null     object
#  18  사용기간      13 non-null     object
#  19  사용상의주의사항  13 non-null     object
#  20  분할선       2 non-null      object
#  21  제품명       2 non-null      object
# dtypes: float64(1), int64(1), object(20)
# memory usage: 2.4+ KB

# %%
df_total = pd.concat([df_all, df_13], ignore_index=True)

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8213 entries, 0 to 8212
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   url       8213 non-null   object
#  1   doc_id    8213 non-null   int64
#  2   약품명       8213 non-null   object
#  3   이미지_URL   4690 non-null   object
#  4   분류        8211 non-null   object
#  5   구분        8213 non-null   object
#  6   업체명       8213 non-null   object
#  7   보험코드      6139 non-null   object
#  8   성상        4690 non-null   object
#  9   제형        4690 non-null   object
#  10  모양        4690 non-null   object
#  11  색깔        4690 non-null   object
#  12  크기        4690 non-null   object
#  13  식별표기      4683 non-null   object
#  14  분할선       1506 non-null   object
#  15  성분정보      8213 non-null   object
#  16  효능효과      8212 non-null   object
#  17  용법용량      8213 non-null   object
#  18  저장방법      8213 non-null   object
#  19  사용기간      8213 non-null   object
#  20  사용상의주의사항  8211 non-null   object
#  21  제품명       1254 non-null   object
# dtypes: int64(1), object(21)
# memory usage: 1.4+ MB

# %%
# 4) 저장
df_total.to_csv("prescription_drug_8213.csv", index=False)

# %%
df_total.head(2)
# Out:
#                                                  url   doc_id  \
# 0  https://terms.naver.com/entry.naver?docId=5661...  5661792
# 1  https://terms.naver.com/entry.naver?docId=4355...  4355082
#
#                   약품명                                            이미지_URL  \
# 0    베스티온정(베포타스틴베실산염)  https://dbscthumb-phinf.pstatic.net/3323_000_3...
# 1  모베타스프레이(모메타손푸로에이트)                                                NaN
#
#               분류     구분         업체명       보험코드             성상     제형  ...  \
# 0  [01410]항히스타민제  전문의약품  에이치엘비제약(주)  647303390  흰색의 원형 필름코팅정제  필름코팅정  ...
# 1   [01320]이비과용제  전문의약품    (주)마더스제약  622803061            NaN    NaN  ...
#
#                           크기     식별표기  분할선                             성분정보  \
# 0  (장축)7.1, (단축)7.1, (두께)3.0  EY, 분할선    -  1정(125.4mg) 중\n베포타스틴베실산염 10.0mg
# 1                        NaN      NaN  NaN           1mL 중\n모메타손푸로에이트 0.5mg
#
#                                                 효능효과  \
# 0  다년성 알레르기성 비염, 만성 두드러기, 피부질환에 수반된 소양증(습진.피부염, 피...
# 1  1. 성인 및 2세 이상의 소아\n: 계절 알레르기비염 및 연중비염. 중등도 ～ 중...
#
#                                                 용법용량               저장방법  \
# 0  통상, 성인에게는 베포타스틴베실산염으로서 1회 10mg을 1일 2회 경구투여한다. ...  기밀용기, 실온(1~30℃)보관
# 1  1. 알레르기 비염\n분무기를 1회 누를 때마다 모메타손푸로에이트 현탁액 약 100...  기밀용기, 실온보관(2～25℃)
#
#            사용기간                                           사용상의주의사항  제품명
# 0  제조일로부터 36 개월  1. 다음 환자에게는 투여하지 말것\n이 약 성분에 과민증이 있는 환자\n\n2. ...  NaN
# 1  제조일로부터 24 개월  1. 다음 환자에는 투여하지 말 것.\n1) 이 약 또는 이 약의 구성성분에 대해 ...  NaN
#
# [2 rows x 22 columns]

# %%
df_total = df_total.drop(columns=['url'])

# %%
df_total = df_total.rename(columns={'doc_id': '문서ID'})

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8213 entries, 0 to 8212
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   문서ID      8213 non-null   int64
#  1   약품명       8213 non-null   object
#  2   이미지_URL   4690 non-null   object
#  3   분류        8211 non-null   object
#  4   구분        8213 non-null   object
#  5   업체명       8213 non-null   object
#  6   보험코드      6139 non-null   object
#  7   성상        4690 non-null   object
#  8   제형        4690 non-null   object
#  9   모양        4690 non-null   object
#  10  색깔        4690 non-null   object
#  11  크기        4690 non-null   object
#  12  식별표기      4683 non-null   object
#  13  분할선       1506 non-null   object
#  14  성분정보      8213 non-null   object
#  15  효능효과      8212 non-null   object
#  16  용법용량      8213 non-null   object
#  17  저장방법      8213 non-null   object
#  18  사용기간      8213 non-null   object
#  19  사용상의주의사항  8211 non-null   object
#  20  제품명       1254 non-null   object
# dtypes: int64(1), object(20)
# memory usage: 1.3+ MB

# %%
df_total.head(3)
# Out:
#       문서ID                 약품명  \
# 0  5661792    베스티온정(베포타스틴베실산염)
# 1  4355082  모베타스프레이(모메타손푸로에이트)
# 2  5769641      프리피펜주(아세트아미노펜)
#
#                                              이미지_URL                분류     구분  \
# 0  https://dbscthumb-phinf.pstatic.net/3323_000_3...     [01410]항히스타민제  전문의약품
# 1                                                NaN      [01320]이비과용제  전문의약품
# 2                                                NaN  [01140]해열.진통.소염제  전문의약품
#
#           업체명       보험코드             성상     제형   모양   색깔  \
# 0  에이치엘비제약(주)  647303390  흰색의 원형 필름코팅정제  필름코팅정   원형   하양
# 1    (주)마더스제약  622803061            NaN    NaN  NaN  NaN
# 2  제이더블유신약(주)        NaN            NaN    NaN  NaN  NaN
#
#                           크기     식별표기  분할선                             성분정보  \
# 0  (장축)7.1, (단축)7.1, (두께)3.0  EY, 분할선    -  1정(125.4mg) 중\n베포타스틴베실산염 10.0mg
# 1                        NaN      NaN  NaN           1mL 중\n모메타손푸로에이트 0.5mg
# 2                        NaN      NaN  NaN          100ml\n아세트아미노펜 1000.0mg
#
#                                                 효능효과  \
# 0  다년성 알레르기성 비염, 만성 두드러기, 피부질환에 수반된 소양증(습진.피부염, 피...
# 1  1. 성인 및 2세 이상의 소아\n: 계절 알레르기비염 및 연중비염. 중등도 ～ 중...
# 2  통증이나 고열로 인하여 신속하게 정맥 투여할 필요가 있거나 다른 경로로 투여할 수 ...
#
#                                                 용법용량               저장방법  \
# 0  통상, 성인에게는 베포타스틴베실산염으로서 1회 10mg을 1일 2회 경구투여한다. ...  기밀용기, 실온(1~30℃)보관
# 1  1. 알레르기 비염\n분무기를 1회 누를 때마다 모메타손푸로에이트 현탁액 약 100...  기밀용기, 실온보관(2～25℃)
# 2  정맥으로 투여하며, 성인, 체중 33kg(약 11세) 이상인 소아에 한함\n\n체중...  밀봉용기, 실온(1-30℃)보관
#
#            사용기간                                           사용상의주의사항
# 0  제조일로부터 36 개월  1. 다음 환자에게는 투여하지 말것\n이 약 성분에 과민증이 있는 환자\n\n2. ...
# 1  제조일로부터 24 개월  1. 다음 환자에는 투여하지 말 것.\n1) 이 약 또는 이 약의 구성성분에 대해 ...
# 2  제조일로부터 24 개월  1. 경고\n1) 투약 오류의 위험: 밀리그램과 밀리리터의 혼동으로 인한 투약 오류...

# %%
df_total = df_total.drop(columns=['제품명'])

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8213 entries, 0 to 8212
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   문서ID      8213 non-null   int64
#  1   약품명       8213 non-null   object
#  2   이미지_URL   4690 non-null   object
#  3   분류        8211 non-null   object
#  4   구분        8213 non-null   object
#  5   업체명       8213 non-null   object
#  6   보험코드      6139 non-null   object
#  7   성상        4690 non-null   object
#  8   제형        4690 non-null   object
#  9   모양        4690 non-null   object
#  10  색깔        4690 non-null   object
#  11  크기        4690 non-null   object
#  12  식별표기      4683 non-null   object
#  13  분할선       1506 non-null   object
#  14  성분정보      8213 non-null   object
#  15  효능효과      8212 non-null   object
#  16  용법용량      8213 non-null   object
#  17  저장방법      8213 non-null   object
#  18  사용기간      8213 non-null   object
#  19  사용상의주의사항  8211 non-null   object
# dtypes: int64(1), object(19)
# memory usage: 1.3+ MB

# %%
# 분류 컬럼이 비어있는 행 삭제
df_total = df_total.dropna(subset=['분류'])

# %%
df_total = df_total.drop(columns=["성상", "제형", "모양", '색깔', '크기', '식별표기', '분할선', '보험코드'])

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8211 entries, 0 to 8212
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   문서ID      8211 non-null   int64
#  1   약품명       8211 non-null   object
#  2   이미지_URL   4690 non-null   object
#  3   분류        8211 non-null   object
#  4   구분        8211 non-null   object
#  5   업체명       8211 non-null   object
#  6   성분정보      8211 non-null   object
#  7   효능효과      8210 non-null   object
#  8   용법용량      8211 non-null   object
#  9   저장방법      8211 non-null   object
#  10  사용기간      8211 non-null   object
#  11  사용상의주의사항  8209 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 1.1+ MB

# %%
# 효늫효과 컬럼이 비어있는 행 삭제
df_total = df_total.dropna(subset=['효능효과'])

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8210 entries, 0 to 8212
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   문서ID      8210 non-null   int64
#  1   약품명       8210 non-null   object
#  2   이미지_URL   4690 non-null   object
#  3   분류        8210 non-null   object
#  4   구분        8210 non-null   object
#  5   업체명       8210 non-null   object
#  6   성분정보      8210 non-null   object
#  7   효능효과      8210 non-null   object
#  8   용법용량      8210 non-null   object
#  9   저장방법      8210 non-null   object
#  10  사용기간      8210 non-null   object
#  11  사용상의주의사항  8208 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 833.8+ KB

# %%
# 사용상의주의사항 컬럼이 비어있는 행 삭제
df_total = df_total.dropna(subset=['사용상의주의사항'])

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8208 entries, 0 to 8212
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   문서ID      8208 non-null   int64
#  1   약품명       8208 non-null   object
#  2   이미지_URL   4688 non-null   object
#  3   분류        8208 non-null   object
#  4   구분        8208 non-null   object
#  5   업체명       8208 non-null   object
#  6   성분정보      8208 non-null   object
#  7   효능효과      8208 non-null   object
#  8   용법용량      8208 non-null   object
#  9   저장방법      8208 non-null   object
#  10  사용기간      8208 non-null   object
#  11  사용상의주의사항  8208 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 833.6+ KB

# %%
df_total = df_total.drop(columns=["구분"])

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8208 entries, 0 to 8212
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   문서ID      8208 non-null   int64
#  1   약품명       8208 non-null   object
#  2   이미지_URL   4688 non-null   object
#  3   분류        8208 non-null   object
#  4   업체명       8208 non-null   object
#  5   성분정보      8208 non-null   object
#  6   효능효과      8208 non-null   object
#  7   용법용량      8208 non-null   object
#  8   저장방법      8208 non-null   object
#  9   사용기간      8208 non-null   object
#  10  사용상의주의사항  8208 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 769.5+ KB

# %%
df_total.to_csv("prescription_drugs_8208.csv", index=False)

# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/envs/medicine_crawler/bin/python

# %% [markdown]
# # firebase 에 csv 업로드하기
# - 전문의약품(prescription_drugs_8208.csv)
# - 일반의약품(oct_drugs_4771.csv)

# %%
pip install firebase-admin pandas tqdm # 패키지 설치
# Out:
# Collecting firebase-admin
#   Downloading firebase_admin-7.1.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/medicine_crawler/lib/python3.10/site-packages (2.3.3)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting cachecontrol>=0.14.3 (from firebase-admin)
#   Downloading cachecontrol-0.14.4-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-api-core<3.0.0dev,>=2.25.1 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-cloud-firestore>=2.21.0 (from firebase-admin)
#   Downloading google_cloud_firestore-2.21.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting google-cloud-storage>=3.1.1 (from firebase-admin)
#   Downloading google_cloud_storage-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting pyjwt>=2.10.1 (from pyjwt[crypto]>=2.10.1->firebase-admin)
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting httpx==0.28.1 (from httpx[http2]==0.28.1->firebase-admin)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting anyio (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin)
#   Downloading anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting certifi (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h2<5,>=3 (from httpx[http2]==0.28.1->firebase-admin)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3.0.0,>=2.14.1 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting requests<3.0.0,>=2.18.0 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading grpcio-1.76.0-cp310-cp310-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading grpcio_status-1.76.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions~=4.12 in /opt/anaconda3/envs/medicine_crawler/lib/python3.10/site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (4.15.0)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading charset_normalizer-3.4.4-cp310-cp310-macosx_10_9_universal2.whl.metadata (37 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.22.4 in /opt/anaconda3/envs/medicine_crawler/lib/python3.10/site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/medicine_crawler/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/medicine_crawler/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/medicine_crawler/lib/python3.10/site-packages (from pandas) (2025.2)
# Collecting msgpack<2.0.0,>=0.5.2 (from cachecontrol>=0.14.3->firebase-admin)
#   Downloading msgpack-1.1.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting google-cloud-core<3.0.0,>=1.4.1 (from google-cloud-firestore>=2.21.0->firebase-admin)
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage>=3.1.1->firebase-admin)
#   Downloading google_resumable_media-2.8.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage>=3.1.1->firebase-admin)
#   Downloading google_crc32c-1.7.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (2.3 kB)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.10.1->firebase-admin)
#   Downloading cryptography-46.0.3-cp38-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting cffi>=2.0.0 (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase-admin)
#   Downloading cffi-2.0.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase-admin)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/medicine_crawler/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/anaconda3/envs/medicine_crawler/lib/python3.10/site-packages (from anyio->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.3.0)
# Downloading firebase_admin-7.1.0-py3-none-any.whl (137 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Downloading cachetools-6.2.2-py3-none-any.whl (11 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading grpcio-1.76.0-cp310-cp310-macosx_11_0_universal2.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 26.0 MB/s  0:00:00 eta 0:00:01
# Downloading grpcio_status-1.76.0-py3-none-any.whl (14 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp310-cp310-macosx_10_9_universal2.whl (209 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading cachecontrol-0.14.4-py3-none-any.whl (22 kB)
# Downloading msgpack-1.1.2-cp310-cp310-macosx_11_0_arm64.whl (83 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading google_cloud_firestore-2.21.0-py3-none-any.whl (368 kB)
# Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Downloading google_cloud_storage-3.6.0-py3-none-any.whl (299 kB)
# Downloading google_crc32c-1.7.1-cp310-cp310-macosx_12_0_arm64.whl (30 kB)
# Downloading google_resumable_media-2.8.0-py3-none-any.whl (81 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading cryptography-46.0.3-cp38-abi3-macosx_10_9_universal2.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 15.7 MB/s  0:00:00 eta 0:00:01
# Downloading cffi-2.0.0-cp310-cp310-macosx_11_0_arm64.whl (180 kB)
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Installing collected packages: urllib3, tqdm, pyjwt, pycparser, pyasn1, protobuf, msgpack, idna, hyperframe, hpack, h11, grpcio, google-crc32c, charset_normalizer, certifi, cachetools, rsa, requests, pyasn1-modules, proto-plus, httpcore, h2, googleapis-common-protos, google-resumable-media, cffi, anyio, httpx, grpcio-status, google-auth, cryptography, cachecontrol, google-api-core, google-cloud-core, google-cloud-storage, google-cloud-firestore, firebase-admin
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36/36 [firebase-admin]m [google-cloud-firestore]s]
# Successfully installed anyio-4.12.0 cachecontrol-0.14.4 cachetools-6.2.2 certifi-2025.11.12 cffi-2.0.0 charset_normalizer-3.4.4 cryptography-46.0.3 firebase-admin-7.1.0 google-api-core-2.28.1 google-auth-2.43.0 google-cloud-core-2.5.0 google-cloud-firestore-2.21.0 google-cloud-storage-3.6.0 google-crc32c-1.7.1 google-resumable-media-2.8.0 googleapis-common-protos-1.72.0 grpcio-1.76.0 grpcio-status-1.76.0 h11-0.16.0 h2-4.3.0 hpack-4.1.0 httpcore-1.0.9 httpx-0.28.1 hyperframe-6.1.0 idna-3.11 msgpack-1.1.2 proto-plus-1.26.1 protobuf-6.33.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 pycparser-2.23 pyjwt-2.10.1 requests-2.32.5 rsa-4.9.1 tqdm-4.67.1 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.
